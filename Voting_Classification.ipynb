# %% [markdown]
# #### Load word2vec predictions

# %%
import word2vec_wrapped
# Out:
# 2018-05-26 03:26:37,011 : INFO : loading projection weights from data/GoogleNews-vectors-negative300.bin
# 2018-05-26 03:26:40,944 : INFO : loaded (200000, 300) matrix from data/GoogleNews-vectors-negative300.bin

# %%
word2vec_predictions_series = word2vec_wrapped.linear_svc_predictions()

# %%
print(word2vec_predictions_series["000000154087.jpg"])
# Out:
# skis

# %% [markdown]
# #### Load doc2vec predictions

# %%
import doc2vec_wrapped

# %%
doc2vec_predictions_series = doc2vec_wrapped.linear_svc_predictions()
# Out:
# 2018-05-26 03:26:43,164 : INFO : collecting all words and their counts
# 2018-05-26 03:26:43,167 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-05-26 03:26:43,303 : INFO : collected 3702 word types and 10 unique tags from a corpus of 1503 examples and 65463 words
# 2018-05-26 03:26:43,303 : INFO : Loading a fresh vocabulary
# 2018-05-26 03:26:43,309 : INFO : min_count=5 retains 1058 unique words (28% of original 3702, drops 2644)
# 2018-05-26 03:26:43,311 : INFO : min_count=5 leaves 61217 word corpus (93% of original 65463, drops 4246)
# 2018-05-26 03:26:43,316 : INFO : deleting the raw counts dictionary of 3702 items
# 2018-05-26 03:26:43,318 : INFO : sample=0.001 downsamples 71 most-common words
# 2018-05-26 03:26:43,319 : INFO : downsampling leaves estimated 39737 word corpus (64.9% of prior 61217)
# 2018-05-26 03:26:43,327 : INFO : estimated required memory for 1058 words and 400 dimensions: 3932600 bytes
# 2018-05-26 03:26:43,329 : INFO : resetting layer weights
# 2018-05-26 03:26:43,359 : INFO : training model with 1 workers on 1058 vocabulary and 400 features, using sg=1 hs=0 sample=0.001 negative=12 window=8
# 2018-05-26 03:26:43,584 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:43,585 : INFO : EPOCH - 1 : training on 65463 raw words (41232 effective words) took 0.2s, 185257 effective words/s
# 2018-05-26 03:26:43,810 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:43,811 : INFO : EPOCH - 2 : training on 65463 raw words (41111 effective words) took 0.2s, 184870 effective words/s
# 2018-05-26 03:26:44,027 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:44,028 : INFO : EPOCH - 3 : training on 65463 raw words (41258 effective words) took 0.2s, 194030 effective words/s
# 2018-05-26 03:26:44,252 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:44,253 : INFO : EPOCH - 4 : training on 65463 raw words (41138 effective words) took 0.2s, 185019 effective words/s
# 2018-05-26 03:26:44,474 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:44,475 : INFO : EPOCH - 5 : training on 65463 raw words (41386 effective words) took 0.2s, 190140 effective words/s
# 2018-05-26 03:26:44,699 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:44,700 : INFO : EPOCH - 6 : training on 65463 raw words (41225 effective words) took 0.2s, 187015 effective words/s
# 2018-05-26 03:26:44,917 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:44,918 : INFO : EPOCH - 7 : training on 65463 raw words (41396 effective words) took 0.2s, 192370 effective words/s
# 2018-05-26 03:26:45,139 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:45,140 : INFO : EPOCH - 8 : training on 65463 raw words (41267 effective words) took 0.2s, 188143 effective words/s
# 2018-05-26 03:26:45,368 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:45,369 : INFO : EPOCH - 9 : training on 65463 raw words (41227 effective words) took 0.2s, 182555 effective words/s
# 2018-05-26 03:26:45,562 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:45,563 : INFO : EPOCH - 10 : training on 65463 raw words (41149 effective words) took 0.2s, 215770 effective words/s
# 2018-05-26 03:26:45,563 : INFO : training on a 654630 raw words (412389 effective words) took 2.2s, 187137 effective words/s

# %%
print(doc2vec_predictions_series["000000154087.jpg"])
# Out:
# skis

# %%
doc2vec_predictions_lr_series = doc2vec_wrapped.logistic_regression_predictions() # logistic regression
# Out:
# 2018-05-26 03:26:48,036 : INFO : collecting all words and their counts
# 2018-05-26 03:26:48,041 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-05-26 03:26:48,071 : INFO : collected 3702 word types and 10 unique tags from a corpus of 1503 examples and 65463 words
# 2018-05-26 03:26:48,073 : INFO : Loading a fresh vocabulary
# 2018-05-26 03:26:48,080 : INFO : min_count=5 retains 1058 unique words (28% of original 3702, drops 2644)
# 2018-05-26 03:26:48,081 : INFO : min_count=5 leaves 61217 word corpus (93% of original 65463, drops 4246)
# 2018-05-26 03:26:48,088 : INFO : deleting the raw counts dictionary of 3702 items
# 2018-05-26 03:26:48,089 : INFO : sample=0.001 downsamples 71 most-common words
# 2018-05-26 03:26:48,091 : INFO : downsampling leaves estimated 39737 word corpus (64.9% of prior 61217)
# 2018-05-26 03:26:48,096 : INFO : estimated required memory for 1058 words and 400 dimensions: 3932600 bytes
# 2018-05-26 03:26:48,098 : INFO : resetting layer weights
# 2018-05-26 03:26:48,135 : INFO : training model with 1 workers on 1058 vocabulary and 400 features, using sg=1 hs=0 sample=0.001 negative=12 window=8
# 2018-05-26 03:26:48,365 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:48,366 : INFO : EPOCH - 1 : training on 65463 raw words (41232 effective words) took 0.2s, 182217 effective words/s
# 2018-05-26 03:26:48,570 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:48,571 : INFO : EPOCH - 2 : training on 65463 raw words (41111 effective words) took 0.2s, 204777 effective words/s
# 2018-05-26 03:26:48,931 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:48,932 : INFO : EPOCH - 3 : training on 65463 raw words (41258 effective words) took 0.4s, 115913 effective words/s
# 2018-05-26 03:26:49,174 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:49,175 : INFO : EPOCH - 4 : training on 65463 raw words (41138 effective words) took 0.2s, 171572 effective words/s
# 2018-05-26 03:26:49,409 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:49,411 : INFO : EPOCH - 5 : training on 65463 raw words (41386 effective words) took 0.2s, 177453 effective words/s
# 2018-05-26 03:26:49,704 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:49,705 : INFO : EPOCH - 6 : training on 65463 raw words (41225 effective words) took 0.3s, 142162 effective words/s
# 2018-05-26 03:26:50,021 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:50,022 : INFO : EPOCH - 7 : training on 65463 raw words (41396 effective words) took 0.3s, 135532 effective words/s
# 2018-05-26 03:26:50,230 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:50,231 : INFO : EPOCH - 8 : training on 65463 raw words (41267 effective words) took 0.2s, 199656 effective words/s
# 2018-05-26 03:26:50,464 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:50,465 : INFO : EPOCH - 9 : training on 65463 raw words (41227 effective words) took 0.2s, 178238 effective words/s
# 2018-05-26 03:26:50,685 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-26 03:26:50,686 : INFO : EPOCH - 10 : training on 65463 raw words (41149 effective words) took 0.2s, 188849 effective words/s
# 2018-05-26 03:26:50,687 : INFO : training on a 654630 raw words (412389 effective words) took 2.6s, 161673 effective words/s

# %%
print(doc2vec_predictions_lr_series["000000154087.jpg"])
# Out:
# skis

# %% [markdown]
# #### Inception images vectors

# %%
import pandas as pd

# %%
inception_df = pd.read_json("data/inception_output.txt", lines=True)
inception_df.set_index('image',inplace=True)
inception_df[:5]
# Out:
#                                                              vector
# image
# 000000173830.jpg  [0.27057743072509705, 0.11477771401405301, 0.0...
# 000000570664.jpg  [0.252127289772033, 0.434070438146591, 0.22712...
# 000000304396.jpg  [0.24179434776306102, 0.08653920888900701, 0.1...
# 000000441491.jpg  [0.11056154966354301, 0.08768206834793, 0.0857...
# 000000289059.jpg  [0.23210205137729603, 0.1578049659729, 0.27599...

# %% [markdown]
# ### Load data and assign predictions

# %%
df = pd.read_json("data/COCO/coco-easier.txt", lines=True)
df = df[['file_name', 'category']]
df = df.sample(frac=1).reset_index(drop=True)

df[:5]
# Out:
#           file_name category
# 0  000000392818.jpg      dog
# 1  000000272416.jpg   toilet
# 2  000000153782.jpg    clock
# 3  000000112634.jpg  giraffe
# 4  000000384661.jpg    clock

# %%
df["inception_vec"] = df.apply(lambda row: inception_df['vector'][row["file_name"]], axis=1)
df[:5]
# Out:
#           file_name category  \
# 0  000000392818.jpg      dog
# 1  000000272416.jpg   toilet
# 2  000000153782.jpg    clock
# 3  000000112634.jpg  giraffe
# 4  000000384661.jpg    clock
#
#                                        inception_vec
# 0  [0.17469400167465202, 0.26662161946296603, 0.0...
# 1  [0.188848942518234, 0.301357805728912, 0.02198...
# 2  [0.23378969728946603, 0.039209499955177, 0.200...
# 3  [0.11513800173997801, 0.16411854326725, 0.1344...
# 4  [0.079583458602428, 0.055941071361303, 0.12203...

# %% [markdown]
# #### Inception classification

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %%
# Returns the mean accuracy on the given test data and labels, in 5 cross validation splits
scores = cross_val_score(classifier, 
                         pd.DataFrame(df["inception_vec"].tolist()), 
                         df["category"].values, 
                         cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.91 (+/- 0.02)

# %%
from sklearn.svm import LinearSVC
classifier = LinearSVC()

# %%
# Returns the mean accuracy on the given test data and labels, in 5 cross validation splits
scores = cross_val_score(classifier, 
                         pd.DataFrame(df["inception_vec"].tolist()), 
                         df["category"].values, 
                         cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.91 (+/- 0.03)

# %%
from sklearn.model_selection import cross_val_predict

df["inception"] = cross_val_predict(classifier, 
                                      pd.DataFrame(df["inception_vec"].tolist()), 
                                      df["category"].values, 
                                      cv=5)
df[:5]
# Out:
#           file_name category  \
# 0  000000392818.jpg      dog
# 1  000000272416.jpg   toilet
# 2  000000153782.jpg    clock
# 3  000000112634.jpg  giraffe
# 4  000000384661.jpg    clock
#
#                                        inception_vec inception
# 0  [0.17469400167465202, 0.26662161946296603, 0.0...       dog
# 1  [0.188848942518234, 0.301357805728912, 0.02198...    toilet
# 2  [0.23378969728946603, 0.039209499955177, 0.200...     clock
# 3  [0.11513800173997801, 0.16411854326725, 0.1344...   giraffe
# 4  [0.079583458602428, 0.055941071361303, 0.12203...     clock

# %%
df["word2vec"] = df.apply(lambda row: word2vec_predictions_series[row["file_name"]], axis=1)
df[:5]
# Out:
#           file_name category  \
# 0  000000392818.jpg      dog
# 1  000000272416.jpg   toilet
# 2  000000153782.jpg    clock
# 3  000000112634.jpg  giraffe
# 4  000000384661.jpg    clock
#
#                                        inception_vec inception word2vec
# 0  [0.17469400167465202, 0.26662161946296603, 0.0...       dog      dog
# 1  [0.188848942518234, 0.301357805728912, 0.02198...    toilet   toilet
# 2  [0.23378969728946603, 0.039209499955177, 0.200...     clock    clock
# 3  [0.11513800173997801, 0.16411854326725, 0.1344...   giraffe  giraffe
# 4  [0.079583458602428, 0.055941071361303, 0.12203...     clock    clock

# %%
df["doc2vec"] = df.apply(lambda row: doc2vec_predictions_series[row["file_name"]], axis=1)
df[:5]
# Out:
#           file_name category  \
# 0  000000392818.jpg      dog
# 1  000000272416.jpg   toilet
# 2  000000153782.jpg    clock
# 3  000000112634.jpg  giraffe
# 4  000000384661.jpg    clock
#
#                                        inception_vec inception word2vec  \
# 0  [0.17469400167465202, 0.26662161946296603, 0.0...       dog      dog
# 1  [0.188848942518234, 0.301357805728912, 0.02198...    toilet   toilet
# 2  [0.23378969728946603, 0.039209499955177, 0.200...     clock    clock
# 3  [0.11513800173997801, 0.16411854326725, 0.1344...   giraffe  giraffe
# 4  [0.079583458602428, 0.055941071361303, 0.12203...     clock    clock
#
#    doc2vec
# 0      dog
# 1   toilet
# 2    clock
# 3  giraffe
# 4    clock

# %%
#df["doc2vec_lr"] = df.apply(lambda row: doc2vec_predictions_lr_series[row["file_name"]], axis=1)
#df[:5]

# %%
collision_df = df.loc[(df.word2vec != df.doc2vec) | (df.word2vec != df.inception) | (df.doc2vec != df.inception)]
collision_df = collision_df.sample(frac=1).reset_index(drop=True)
collision_df[:5]
# Out:
#           file_name       category  \
# 0  000000520659.jpg      surfboard
# 1  000000215723.jpg  traffic light
# 2  000000055528.jpg          clock
# 3  000000035770.jpg         toilet
# 4  000000097994.jpg          clock
#
#                                        inception_vec      inception  \
# 0  [0.7100997567176811, 0.456843733787536, 0.0986...  traffic light
# 1  [0.192710846662521, 0.19607912003993902, 0.515...            dog
# 2  [0.30422067642211903, 0.18106706440448703, 0.6...            cat
# 3  [1.375411033630371, 0.7606959939002991, 0.4556...          pizza
# 4  [0.614293277263641, 0.089026249945163, 1.14133...            cat
#
#         word2vec        doc2vec
# 0      surfboard      surfboard
# 1  traffic light  traffic light
# 2          clock          clock
# 3         toilet         toilet
# 4          clock            cat

# %%
def vote_prediction(row):
    predictions = [row["word2vec"], row["doc2vec"], row["inception"]]
    return max(set(predictions), key=predictions.count)

# %%
df["voted"] = df.apply(lambda row: vote_prediction(row), axis=1)
df[:5]
# Out:
#           file_name category  \
# 0  000000392818.jpg      dog
# 1  000000272416.jpg   toilet
# 2  000000153782.jpg    clock
# 3  000000112634.jpg  giraffe
# 4  000000384661.jpg    clock
#
#                                        inception_vec inception word2vec  \
# 0  [0.17469400167465202, 0.26662161946296603, 0.0...       dog      dog
# 1  [0.188848942518234, 0.301357805728912, 0.02198...    toilet   toilet
# 2  [0.23378969728946603, 0.039209499955177, 0.200...     clock    clock
# 3  [0.11513800173997801, 0.16411854326725, 0.1344...   giraffe  giraffe
# 4  [0.079583458602428, 0.055941071361303, 0.12203...     clock    clock
#
#    doc2vec    voted
# 0      dog      dog
# 1   toilet   toilet
# 2    clock    clock
# 3  giraffe  giraffe
# 4    clock    clock

# %%
collision_df = df.loc[(df.word2vec != df.doc2vec) | (df.word2vec != df.inception) | (df.doc2vec != df.inception)]
collision_df = collision_df.sample(frac=1).reset_index(drop=True)
collision_df[:5]
# Out:
#           file_name category  \
# 0  000000554579.jpg      dog
# 1  000000315492.jpg   toilet
# 2  000000402720.jpg    pizza
# 3  000000176857.jpg      cat
# 4  000000371749.jpg      dog
#
#                                        inception_vec inception word2vec  \
# 0  [0.48696273565292303, 0.325279921293258, 0.163...       cat      dog
# 1  [0.5040708780288691, 0.31624710559844904, 0.18...       cat   toilet
# 2  [0.6898229122161861, 0.051462326198816, 0.1597...     clock    pizza
# 3  [0.305775940418243, 0.7700119614601131, 0.2770...     clock      cat
# 4  [0.22384999692440002, 0.5431106686592101, 0.29...       dog    clock
#
#   doc2vec   voted
# 0     dog     dog
# 1  toilet  toilet
# 2   pizza   pizza
# 3     dog   clock
# 4   clock   clock

# %% [markdown]
# ## Evaluation and testing

# %%
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(df["category"], df["voted"])
print("Accuracy: %0.2f" % (score))
# Out:
# Accuracy: 0.97

# %% [markdown]
# #### Misclassified

# %%
k1 = df.loc[(df.category != df.voted)]
k1 = k1.sample(frac=1).reset_index(drop=True)
k1
# Out:
#            file_name       category  \
# 0   000000365642.jpg         toilet
# 1   000000473869.jpg          pizza
# 2   000000289393.jpg        giraffe
# 3   000000463522.jpg            dog
# 4   000000371749.jpg            dog
# 5   000000139684.jpg            cat
# 6   000000045550.jpg          clock
# 7   000000565877.jpg          clock
# 8   000000199771.jpg          clock
# 9   000000015956.jpg          clock
# 10  000000270883.jpg          clock
# 11  000000369675.jpg          clock
# 12  000000279278.jpg            dog
# 13  000000076547.jpg  traffic light
# 14  000000139099.jpg            dog
# 15  000000407614.jpg      surfboard
# 16  000000545100.jpg  traffic light
# 17  000000442746.jpg  traffic light
# 18  000000057760.jpg            dog
# 19  000000375493.jpg            cat
# 20  000000571804.jpg         toilet
# 21  000000279145.jpg            cat
# 22  000000097994.jpg          clock
# 23  000000491464.jpg  traffic light
# 24  000000412240.jpg            dog
# 25  000000180101.jpg          pizza
# 26  000000092177.jpg      surfboard
# 27  000000084674.jpg          clock
# 28  000000289343.jpg            dog
# 29  000000350148.jpg          clock
# 30  000000366884.jpg            dog
# 31  000000496854.jpg  traffic light
# 32  000000213255.jpg  traffic light
# 33  000000405195.jpg          clock
# 34  000000507037.jpg          pizza
# 35  000000091500.jpg          pizza
# 36  000000009590.jpg          clock
# 37  000000176857.jpg            cat
# 38  000000146825.jpg          clock
# 39  000000393569.jpg         toilet
# 40  000000471789.jpg            dog
# 41  000000262048.jpg      surfboard
# 42  000000520264.jpg          pizza
# 43  000000458255.jpg            cat
# 44  000000233771.jpg          clock
# 45  000000366141.jpg            cat
# 46  000000238410.jpg          clock
# 47  000000087476.jpg      surfboard
# 48  000000327592.jpg          clock
# 49  000000167122.jpg            cat
# 50  000000143961.jpg            dog
#
#                                         inception_vec      inception  \
# 0   [0.011585621163249, 0.11454046517610501, 0.368...  traffic light
# 1   [0.45494794845581005, 0.098680987954139, 0.861...            dog
# 2   [0.39394444227218606, 0.07610823214054101, 0.0...            dog
# 3   [0.199311554431915, 0.252430081367492, 0.16357...  traffic light
# 4   [0.22384999692440002, 0.5431106686592101, 0.29...            dog
# 5   [0.847091734409332, 0.09708552807569501, 0.025...          clock
# 6   [0.36582556366920405, 0.116934947669506, 0.564...          pizza
# 7   [0.47440463304519603, 0.057121068239212, 0.249...            cat
# 8   [0.504446506500244, 0.43583330512046803, 1.276...          pizza
# 9   [0.197224363684654, 0.23241095244884402, 0.236...            dog
# 10  [0.7639112472534181, 0.17300772666931102, 0.41...            cat
# 11  [0.30112716555595404, 0.339799255132675, 0.728...  traffic light
# 12  [0.32426470518112105, 0.6477996110916131, 0.09...            dog
# 13  [1.047051191329956, 0.5537039637565611, 0.9865...          clock
# 14  [0.09454352408647501, 0.265006422996521, 0.361...  traffic light
# 15  [0.662172794342041, 0.284033894538879, 0.01453...          clock
# 16  [0.19145303964614802, 0.5472779870033261, 1.10...  traffic light
# 17  [0.429553806781768, 0.059800717979669, 0.26138...            dog
# 18  [0.083211362361907, 0.160341203212738, 0.18065...      surfboard
# 19  [0.170695602893829, 0.37083226442337003, 0.221...  traffic light
# 20  [0.21919454634189603, 0.535650134086608, 0.363...          clock
# 21  [0.07438386976718901, 0.45561227202415405, 0.1...            dog
# 22  [0.614293277263641, 0.089026249945163, 1.14133...            cat
# 23  [0.24657610058784402, 0.09064880013465801, 0.6...  tennis racket
# 24  [0.684308946132659, 0.5132367610931391, 0.4394...            cat
# 25  [0.198802322149276, 0.613025069236755, 0.13692...          pizza
# 26  [0.080746568739414, 0.262247085571289, 0.35499...            dog
# 27  [0.411201775074005, 0.14782258868217402, 0.588...          clock
# 28  [0.043929178267717, 0.21304532885551403, 0.077...  traffic light
# 29  [0.12136806547641701, 0.133482441306114, 0.777...          pizza
# 30  [0.39259368181228604, 0.065860405564308, 0.471...            cat
# 31  [0.000702583929523, 0.28323972225189203, 0.237...          clock
# 32  [0.17541798949241602, 0.41881451010704, 0.1833...          pizza
# 33  [0.38695654273033103, 0.31199276447296104, 0.1...          pizza
# 34  [0.16434085369110102, 0.20582765340805, 0.2060...            dog
# 35  [0.771896839141845, 0.183289766311645, 0.80438...          clock
# 36  [0.33068212866783103, 0.27205741405487, 0.4715...          clock
# 37  [0.305775940418243, 0.7700119614601131, 0.2770...          clock
# 38  [0.9113170504570001, 0.225520461797714, 0.8164...  traffic light
# 39  [0.228228256106376, 0.586486101150512, 0.25542...         toilet
# 40  [0.5145166516304011, 0.35966360569000205, 0.29...  traffic light
# 41  [0.178410589694976, 0.188959956169128, 0.06696...          clock
# 42  [1.587045192718505, 0.171012833714485, 0.41941...          clock
# 43  [0.43744236230850203, 0.6692507266998291, 0.55...            dog
# 44  [0.026787614449858003, 0.08983166515827101, 0....  traffic light
# 45  [0.529700636863708, 0.180669605731964, 0.01814...          clock
# 46  [0.050130717456340006, 0.611100137233734, 0.15...          clock
# 47  [0.5537114143371581, 0.369018137454986, 0.3297...  tennis racket
# 48  [0.176276385784149, 0.310146749019622, 0.11239...          pizza
# 49  [0.41401070356369, 0.40878722071647605, 0.1327...  traffic light
# 50  [0.042600248008966, 0.102524101734161, 0.12920...          clock
#
#          word2vec        doc2vec          voted
# 0   traffic light  traffic light  traffic light
# 1           clock          pizza          clock
# 2             dog        giraffe            dog
# 3   traffic light  traffic light  traffic light
# 4           clock          clock          clock
# 5           clock          clock          clock
# 6           pizza          pizza          pizza
# 7           clock            cat            cat
# 8           pizza            dog          pizza
# 9             dog            dog            dog
# 10         toilet            dog            dog
# 11  traffic light  traffic light  traffic light
# 12  traffic light  traffic light  traffic light
# 13          clock          clock          clock
# 14  traffic light            dog  traffic light
# 15          clock          clock          clock
# 16          clock          clock          clock
# 17            dog  tennis racket            dog
# 18      surfboard            dog      surfboard
# 19  traffic light  traffic light  traffic light
# 20          clock         toilet          clock
# 21          clock            cat          clock
# 22          clock            cat            cat
# 23  tennis racket  tennis racket  tennis racket
# 24            dog            cat            cat
# 25          clock          clock          clock
# 26          clock          clock          clock
# 27          pizza          pizza          pizza
# 28  traffic light  traffic light  traffic light
# 29          pizza          pizza          pizza
# 30          clock            cat            cat
# 31          clock  traffic light          clock
# 32            dog            dog            dog
# 33          pizza          clock          pizza
# 34          clock          clock          clock
# 35          clock          clock          clock
# 36          pizza          pizza          pizza
# 37            cat            dog          clock
# 38  traffic light          clock  traffic light
# 39          clock          clock          clock
# 40           skis            dog  traffic light
# 41      surfboard            dog          clock
# 42          clock          clock          clock
# 43            cat            dog            dog
# 44  traffic light          clock  traffic light
# 45          clock          clock          clock
# 46          pizza          pizza          pizza
# 47  traffic light      surfboard  traffic light
# 48          pizza          pizza          pizza
# 49            cat  traffic light  traffic light
# 50          clock  traffic light          clock

# %%
from IPython.display import Image

# %%
# Interesting example of misclassification. Original: traffic light, prediction: tennis racket
Image('data/COCO/easier/000000491464.jpg')

# %%
# Interesting example of misclassification. Original: dog, prediction: surfboard
Image('data/COCO/easier/000000057760.jpg')
