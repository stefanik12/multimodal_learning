# %% [markdown]
# #### Load word2vec predictions

# %%
import word2vec_wrapped
# Out:
# 2018-05-24 20:13:34,335 : INFO : loading projection weights from data/GoogleNews-vectors-negative300.bin
# 2018-05-24 20:13:37,321 : INFO : loaded (200000, 300) matrix from data/GoogleNews-vectors-negative300.bin

# %%
word2vec_predictions_series = word2vec_wrapped.linear_svc_predictions()

# %%
print(word2vec_predictions_series["000000154087.jpg"])
# Out:
# skis

# %% [markdown]
# #### Load doc2vec predictions

# %%
import doc2vec_wrapped

# %%
doc2vec_predictions_series = doc2vec_wrapped.linear_svc_predictions()
# Out:
# 2018-05-24 20:13:39,129 : INFO : collecting all words and their counts
# 2018-05-24 20:13:39,131 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-05-24 20:13:39,149 : INFO : collected 3702 word types and 10 unique tags from a corpus of 1503 examples and 65463 words
# 2018-05-24 20:13:39,150 : INFO : Loading a fresh vocabulary
# 2018-05-24 20:13:39,155 : INFO : min_count=5 retains 1058 unique words (28% of original 3702, drops 2644)
# 2018-05-24 20:13:39,156 : INFO : min_count=5 leaves 61217 word corpus (93% of original 65463, drops 4246)
# 2018-05-24 20:13:39,160 : INFO : deleting the raw counts dictionary of 3702 items
# 2018-05-24 20:13:39,163 : INFO : sample=0.001 downsamples 71 most-common words
# 2018-05-24 20:13:39,164 : INFO : downsampling leaves estimated 39737 word corpus (64.9% of prior 61217)
# 2018-05-24 20:13:39,168 : INFO : estimated required memory for 1058 words and 400 dimensions: 3932600 bytes
# 2018-05-24 20:13:39,168 : INFO : resetting layer weights
# 2018-05-24 20:13:39,194 : INFO : training model with 1 workers on 1058 vocabulary and 400 features, using sg=1 hs=0 sample=0.001 negative=12 window=8
# 2018-05-24 20:13:39,372 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:39,374 : INFO : EPOCH - 1 : training on 65463 raw words (41232 effective words) took 0.2s, 234288 effective words/s
# 2018-05-24 20:13:39,558 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:39,559 : INFO : EPOCH - 2 : training on 65463 raw words (41111 effective words) took 0.2s, 228100 effective words/s
# 2018-05-24 20:13:39,719 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:39,720 : INFO : EPOCH - 3 : training on 65463 raw words (41258 effective words) took 0.2s, 262806 effective words/s
# 2018-05-24 20:13:39,884 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:39,885 : INFO : EPOCH - 4 : training on 65463 raw words (41138 effective words) took 0.2s, 253835 effective words/s
# 2018-05-24 20:13:40,068 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:40,069 : INFO : EPOCH - 5 : training on 65463 raw words (41386 effective words) took 0.2s, 228687 effective words/s
# 2018-05-24 20:13:40,242 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:40,243 : INFO : EPOCH - 6 : training on 65463 raw words (41225 effective words) took 0.2s, 241068 effective words/s
# 2018-05-24 20:13:40,423 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:40,424 : INFO : EPOCH - 7 : training on 65463 raw words (41396 effective words) took 0.2s, 232526 effective words/s
# 2018-05-24 20:13:40,596 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:40,596 : INFO : EPOCH - 8 : training on 65463 raw words (41267 effective words) took 0.2s, 243585 effective words/s
# 2018-05-24 20:13:40,757 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:40,758 : INFO : EPOCH - 9 : training on 65463 raw words (41227 effective words) took 0.2s, 261001 effective words/s
# 2018-05-24 20:13:40,926 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:40,927 : INFO : EPOCH - 10 : training on 65463 raw words (41149 effective words) took 0.2s, 246826 effective words/s
# 2018-05-24 20:13:40,928 : INFO : training on a 654630 raw words (412389 effective words) took 1.7s, 238014 effective words/s

# %%
print(doc2vec_predictions_series["000000154087.jpg"])
# Out:
# skis

# %%
doc2vec_predictions_lr_series = doc2vec_wrapped.logistic_regression_predictions() # logistic regression
# Out:
# 2018-05-24 20:13:42,987 : INFO : collecting all words and their counts
# 2018-05-24 20:13:42,988 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-05-24 20:13:43,010 : INFO : collected 3702 word types and 10 unique tags from a corpus of 1503 examples and 65463 words
# 2018-05-24 20:13:43,011 : INFO : Loading a fresh vocabulary
# 2018-05-24 20:13:43,015 : INFO : min_count=5 retains 1058 unique words (28% of original 3702, drops 2644)
# 2018-05-24 20:13:43,017 : INFO : min_count=5 leaves 61217 word corpus (93% of original 65463, drops 4246)
# 2018-05-24 20:13:43,023 : INFO : deleting the raw counts dictionary of 3702 items
# 2018-05-24 20:13:43,024 : INFO : sample=0.001 downsamples 71 most-common words
# 2018-05-24 20:13:43,024 : INFO : downsampling leaves estimated 39737 word corpus (64.9% of prior 61217)
# 2018-05-24 20:13:43,029 : INFO : estimated required memory for 1058 words and 400 dimensions: 3932600 bytes
# 2018-05-24 20:13:43,030 : INFO : resetting layer weights
# 2018-05-24 20:13:43,061 : INFO : training model with 1 workers on 1058 vocabulary and 400 features, using sg=1 hs=0 sample=0.001 negative=12 window=8
# 2018-05-24 20:13:43,243 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:43,244 : INFO : EPOCH - 1 : training on 65463 raw words (41232 effective words) took 0.2s, 228814 effective words/s
# 2018-05-24 20:13:43,423 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:43,424 : INFO : EPOCH - 2 : training on 65463 raw words (41111 effective words) took 0.2s, 233399 effective words/s
# 2018-05-24 20:13:43,610 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:43,611 : INFO : EPOCH - 3 : training on 65463 raw words (41258 effective words) took 0.2s, 224820 effective words/s
# 2018-05-24 20:13:43,789 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:43,790 : INFO : EPOCH - 4 : training on 65463 raw words (41138 effective words) took 0.2s, 234589 effective words/s
# 2018-05-24 20:13:44,096 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:44,096 : INFO : EPOCH - 5 : training on 65463 raw words (41386 effective words) took 0.3s, 137055 effective words/s
# 2018-05-24 20:13:44,459 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:44,460 : INFO : EPOCH - 6 : training on 65463 raw words (41225 effective words) took 0.4s, 115209 effective words/s
# 2018-05-24 20:13:44,662 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:44,663 : INFO : EPOCH - 7 : training on 65463 raw words (41396 effective words) took 0.2s, 206644 effective words/s
# 2018-05-24 20:13:44,824 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:44,825 : INFO : EPOCH - 8 : training on 65463 raw words (41267 effective words) took 0.2s, 260274 effective words/s
# 2018-05-24 20:13:44,985 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:44,986 : INFO : EPOCH - 9 : training on 65463 raw words (41227 effective words) took 0.2s, 260697 effective words/s
# 2018-05-24 20:13:45,147 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-24 20:13:45,148 : INFO : EPOCH - 10 : training on 65463 raw words (41149 effective words) took 0.2s, 259498 effective words/s
# 2018-05-24 20:13:45,149 : INFO : training on a 654630 raw words (412389 effective words) took 2.1s, 197608 effective words/s

# %%
print(doc2vec_predictions_lr_series["000000154087.jpg"])
# Out:
# skis

# %% [markdown]
# ### Load data and assign predictions

# %%
import pandas as pd

# %%
df = pd.read_json("data/COCO/coco-easier.txt", lines=True)
df = df[['file_name', 'category']]
df = df.sample(frac=1).reset_index(drop=True)

df[:5]
# Out:
#           file_name category
# 0  000000171740.jpg    clock
# 1  000000498857.jpg  giraffe
# 2  000000443303.jpg      cat
# 3  000000167898.jpg   toilet
# 4  000000499313.jpg    pizza

# %%
df["word2vec"] = df.apply(lambda row: word2vec_predictions_series[row["file_name"]], axis=1)
df[:5]
# Out:
#           file_name category word2vec
# 0  000000171740.jpg    clock    clock
# 1  000000498857.jpg  giraffe  giraffe
# 2  000000443303.jpg      cat      cat
# 3  000000167898.jpg   toilet   toilet
# 4  000000499313.jpg    pizza    pizza

# %%
df["doc2vec"] = df.apply(lambda row: doc2vec_predictions_series[row["file_name"]], axis=1)
df[:5]
# Out:
#           file_name category word2vec  doc2vec
# 0  000000171740.jpg    clock    clock    clock
# 1  000000498857.jpg  giraffe  giraffe  giraffe
# 2  000000443303.jpg      cat      cat      cat
# 3  000000167898.jpg   toilet   toilet   toilet
# 4  000000499313.jpg    pizza    pizza    pizza

# %%
df["doc2vec_lr"] = df.apply(lambda row: doc2vec_predictions_lr_series[row["file_name"]], axis=1)
df[:5]
# Out:
#           file_name category word2vec  doc2vec doc2vec_lr
# 0  000000171740.jpg    clock    clock    clock      clock
# 1  000000498857.jpg  giraffe  giraffe  giraffe    giraffe
# 2  000000443303.jpg      cat      cat      cat        cat
# 3  000000167898.jpg   toilet   toilet   toilet     toilet
# 4  000000499313.jpg    pizza    pizza    pizza      pizza

# %%
collision_df = df.loc[(df.word2vec != df.doc2vec) | (df.word2vec != df.doc2vec_lr) | (df.doc2vec != df.doc2vec_lr)]
collision_df = collision_df.sample(frac=1).reset_index(drop=True)
collision_df[:5]
# Out:
#           file_name       category       word2vec doc2vec doc2vec_lr
# 0  000000558073.jpg            cat            cat     cat     toilet
# 1  000000508917.jpg          clock  traffic light   clock      clock
# 2  000000169169.jpg  traffic light  traffic light   clock      clock
# 3  000000078565.jpg            dog      surfboard     dog        dog
# 4  000000535253.jpg          pizza            dog   pizza      pizza

# %%
def vote_prediction(row):
    predictions = [row["word2vec"], row["doc2vec"], row["doc2vec_lr"]]
    return max(set(predictions), key=predictions.count)

# %%
df["voted"] = df.apply(lambda row: vote_prediction(row), axis=1)
df[:5]
# Out:
#           file_name category word2vec  doc2vec doc2vec_lr    voted
# 0  000000171740.jpg    clock    clock    clock      clock    clock
# 1  000000498857.jpg  giraffe  giraffe  giraffe    giraffe  giraffe
# 2  000000443303.jpg      cat      cat      cat        cat      cat
# 3  000000167898.jpg   toilet   toilet   toilet     toilet   toilet
# 4  000000499313.jpg    pizza    pizza    pizza      pizza    pizza

# %%
collision_df = df.loc[(df.word2vec != df.doc2vec) | (df.word2vec != df.doc2vec_lr) | (df.doc2vec != df.doc2vec_lr)]
collision_df = collision_df.sample(frac=1).reset_index(drop=True)
collision_df[:5]
# Out:
#           file_name category       word2vec  doc2vec doc2vec_lr    voted
# 0  000000279145.jpg      cat          clock      cat        cat      cat
# 1  000000534270.jpg      dog  traffic light      dog        dog      dog
# 2  000000458255.jpg      cat            cat      dog        dog      dog
# 3  000000289393.jpg  giraffe            dog  giraffe    giraffe  giraffe
# 4  000000146825.jpg    clock  traffic light    clock      clock    clock

# %% [markdown]
# ## Evaluation and testing

# %%
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(df["category"], df["voted"])
print("Accuracy: %0.2f" % (score))
# Out:
# Accuracy: 0.97

# %% [markdown]
# #### Misclassified

# %%
k1 = df.loc[(df.category != df.voted)]
k1 = k1.sample(frac=1).reset_index(drop=True)
k1
# Out:
#            file_name       category       word2vec        doc2vec  \
# 0   000000327592.jpg          clock          pizza          pizza
# 1   000000350148.jpg          clock          pizza          pizza
# 2   000000169169.jpg  traffic light  traffic light          clock
# 3   000000366884.jpg            dog          clock            cat
# 4   000000270883.jpg          clock         toilet            dog
# 5   000000213255.jpg  traffic light            dog            dog
# 6   000000076547.jpg  traffic light          clock          clock
# 7   000000371749.jpg            dog          clock          clock
# 8   000000289343.jpg            dog  traffic light  traffic light
# 9   000000491464.jpg  traffic light  tennis racket  tennis racket
# 10  000000412240.jpg            dog            dog            cat
# 11  000000357888.jpg          clock          clock      surfboard
# 12  000000262048.jpg      surfboard      surfboard            dog
# 13  000000199771.jpg          clock          pizza            dog
# 14  000000565877.jpg          clock          clock            cat
# 15  000000366141.jpg            cat          clock          clock
# 16  000000279278.jpg            dog  traffic light  traffic light
# 17  000000091500.jpg          pizza          clock          clock
# 18  000000442746.jpg  traffic light            dog  tennis racket
# 19  000000365642.jpg         toilet  traffic light  traffic light
# 20  000000507037.jpg          pizza          clock          clock
# 21  000000180101.jpg          pizza          clock          clock
# 22  000000393569.jpg         toilet          clock          clock
# 23  000000407614.jpg      surfboard          clock          clock
# 24  000000015956.jpg          clock            dog            dog
# 25  000000404484.jpg            dog            dog          clock
# 26  000000375493.jpg            cat  traffic light  traffic light
# 27  000000482917.jpg            dog            dog            cat
# 28  000000097994.jpg          clock          clock            cat
# 29  000000009590.jpg          clock          pizza          pizza
# 30  000000463522.jpg            dog  traffic light  traffic light
# 31  000000045550.jpg          clock          pizza          pizza
# 32  000000238410.jpg          clock          pizza          pizza
# 33  000000369675.jpg          clock  traffic light  traffic light
# 34  000000545100.jpg  traffic light          clock          clock
# 35  000000139684.jpg            cat          clock          clock
# 36  000000520264.jpg          pizza          clock          clock
# 37  000000084674.jpg          clock          pizza          pizza
# 38  000000092177.jpg      surfboard          clock          clock
# 39  000000167122.jpg            cat            cat  traffic light
# 40  000000458255.jpg            cat            cat            dog
#
#        doc2vec_lr          voted
# 0           pizza          pizza
# 1           pizza          pizza
# 2           clock          clock
# 3             cat            cat
# 4             dog            dog
# 5             dog            dog
# 6           clock          clock
# 7           clock          clock
# 8   traffic light  traffic light
# 9   tennis racket  tennis racket
# 10            cat            cat
# 11      surfboard      surfboard
# 12            dog            dog
# 13          pizza          pizza
# 14            cat            cat
# 15          clock          clock
# 16  traffic light  traffic light
# 17          clock          clock
# 18  tennis racket  tennis racket
# 19         toilet  traffic light
# 20          clock          clock
# 21          clock          clock
# 22            cat          clock
# 23          clock          clock
# 24            dog            dog
# 25          clock          clock
# 26  traffic light  traffic light
# 27            cat            cat
# 28            cat            cat
# 29          pizza          pizza
# 30  traffic light  traffic light
# 31          pizza          pizza
# 32          pizza          pizza
# 33  traffic light  traffic light
# 34          clock          clock
# 35          clock          clock
# 36          pizza          clock
# 37          pizza          pizza
# 38          clock          clock
# 39  traffic light  traffic light
# 40            dog            dog
