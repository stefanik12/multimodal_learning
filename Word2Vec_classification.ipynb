# %% [markdown]
# ## Word2Vec unimodal classification demo
#
# 1. Vectorize words from captions
#
# 2. Calculate vectors average
#
# 3. Find most similar word to the average vector
#
# 3. Use one or two distinct classifiers to perform the classification
#
# 4. Compute the accuracy of classification with the selected classifiers (LogReg, SVC)

# %%
import pandas as pd

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
df = pd.read_json("data/COCO/coco-easier.txt", 
                  lines=True)
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                          all_categories  \
# 0                                     [dog, dog, couch]
# 1                                                 [cat]
# 2                                            [dog, dog]
# 3     [sports ball, tennis racket, person, person, p...
# 4     [person, person, skis, backpack, person, skis,...
# 5                                            [cat, cat]
# 6       [bottle, traffic light, person, person, person]
# 7                                        [person, skis]
# 8     [bicycle, car, car, traffic light, traffic lig...
# 9                                         [cat, laptop]
# 10                                        [dog, remote]
# 11    [tennis racket, person, person, person, person...
# 12         [couch, person, person, knife, pizza, knife]
# 13                                   [giraffe, giraffe]
# 14                                           [dog, car]
# 15                                       [person, skis]
# 16    [person, tennis racket, sports ball, person, p...
# 17                 [sports ball, person, tennis racket]
# 18       [person, person, tennis racket, person, chair]
# 19    [bottle, bottle, clock, person, person, fork, ...
# 20                                   [giraffe, giraffe]
# 21    [bicycle, car, car, car, person, person, perso...
# 22    [car, car, car, truck, traffic light, person, ...
# 23                                             [toilet]
# 24                [cat, cat, couch, person, wine glass]
# 25                 [giraffe, giraffe, giraffe, giraffe]
# 26    [toothbrush, couch, person, remote, remote, bo...
# 27                                       [toilet, sink]
# 28                                       [clock, clock]
# 29    [traffic light, traffic light, person, bicycle...
# ...                                                 ...
# 1473  [bicycle, bicycle, traffic light, traffic ligh...
# 1474                            [tv, cat, couch, chair]
# 1475                                           [toilet]
# 1476  [chair, chair, chair, chair, dining table, ted...
# 1477  [bottle, bottle, dining table, pizza, person, ...
# 1478  [dog, sheep, sheep, sheep, sheep, person, pers...
# 1479                               [dog, couch, person]
# 1480     [skis, person, person, person, person, person]
# 1481                                           [toilet]
# 1482                                         [cat, car]
# 1483                                     [clock, clock]
# 1484  [chair, chair, chair, person, cup, book, book,...
# 1485  [sports ball, sports ball, person, tennis racket]
# 1486  [person, person, tennis racket, tennis racket,...
# 1487                                            [pizza]
# 1488            [pizza, bowl, chair, dining table, cup]
# 1489  [person, person, person, person, person, perso...
# 1490  [surfboard, surfboard, person, person, person,...
# 1491                        [dining table, fork, pizza]
# 1492                                              [dog]
# 1493  [person, person, cup, pizza, pizza, pizza, bac...
# 1494                                       [cat, chair]
# 1495  [bottle, chair, dining table, car, person, for...
# 1496                                     [person, skis]
# 1497                    [person, person, tennis racket]
# 1498                           [person, backpack, skis]
# 1499  [sports ball, chair, tennis racket, person, pe...
# 1500  [person, skis, person, person, person, person,...
# 1501                              [clock, clock, clock]
# 1502                            [person, tennis racket]
#
#                                                captions       category  \
# 0     [two dogs laying down on a brown couch, there ...            dog
# 1     [An orange cat sitting in front of a door to a...            cat
# 2     [A brown and white dog standing next to anothe...            dog
# 3     [A man standing on a clay tennis court with a ...  tennis racket
# 4     [A man riding skis down a snow covered slope.,...           skis
# 5     [A cat that is standing looking through a glas...            cat
# 6     [Street art painted on the wall in an asian co...  traffic light
# 7     [A skier in a squat position on skies skiing d...           skis
# 8     [a blue bike parked on a side walk , A bicycle...  traffic light
# 9     [A fluffy cat laying on an electronic device, ...            cat
# 10    [a dog is laying with a remote controller, A d...            dog
# 11    [a tennis player hitting a serve on a court, A...  tennis racket
# 12    [a young woman with a slice of pizza in her mo...          pizza
# 13    [Two giraffes are shown standing in a grassy f...        giraffe
# 14    [A dog driving an SUV in an open grass covered...            dog
# 15    [A person skis down a snowy hill. , a person s...           skis
# 16    [A man holding a tennis racquet on a court., A...  tennis racket
# 17    [A woman in black shirt and skirt playing a ga...  tennis racket
# 18    [A man on a court swinging a tennis racket., A...  tennis racket
# 19    [A man in a green shirt stands by a girl holdi...          clock
# 20    [The two giraffes are standing in the dirt., t...        giraffe
# 21    [A woman walking next to a man riding a pink b...  traffic light
# 22    [A snowy ladnscape with a car crashed into a p...  traffic light
# 23    [A toilet that is decorated like a pink stuffe...         toilet
# 24    [A man sits on the couch with two cats on his ...            cat
# 25    [A herd of giraffe standing next to each other...        giraffe
# 26    [A man holding a paper bag while showing the c...          clock
# 27    [A cream colored bathroom is clean and empty.,...         toilet
# 28    [The building has a light pole with for lights...          clock
# 29    [cars setting at traffic light leading to capi...  traffic light
# ...                                                 ...            ...
# 1473  [A city sidewalk with people walking up and do...  traffic light
# 1474  [a cat laying on top of a chair in the living ...            cat
# 1475  [a toilet with glitter paint on it , A dirty w...         toilet
# 1476  [A group of teddy bears sitting at a small tab...          clock
# 1477  [A small toy sits on a plate with pizza and cr...          pizza
# 1478  [a sheep in a field with a dog and people watc...            dog
# 1479  [Nothing is quite as soft as a young puppy., A...            dog
# 1480  [a man skiing along a rail on the snowy hill ,...           skis
# 1481  [Bathroom stall with green door in commercial ...         toilet
# 1482  [A orange calico cat on top of a vehicle., a c...            cat
# 1483  [A display of clocks inside a shop window., Tw...          clock
# 1484  [A shot of an elderly man inside a kitchen., A...          clock
# 1485  [A man swinging a tennis racquet on a tennis c...  tennis racket
# 1486  [Two people standing on a tennis court playing...  tennis racket
# 1487  [A pepperoni pizza sitting on top of a wooden ...          pizza
# 1488  [A pizza sitting on top of a white plate next ...          pizza
# 1489  [people standing in line on a hill in snow gea...           skis
# 1490  [Two people standing on a beach next to the oc...      surfboard
# 1491  [There are meats and vegetables on a flatbread...          pizza
# 1492  [a dog that's been playing in the water, A wet...            dog
# 1493  [A woman sitting in front of a giant pizza., T...          pizza
# 1494  [a cat sitting in a chair looking up, Gray cat...            cat
# 1495  [A close up of a pizza pie sitting on a table....          pizza
# 1496  [a person riding skis on a snowy slope, A man ...           skis
# 1497  [A man standing on a tennis court holding a ra...  tennis racket
# 1498  [a person riding skis on a snowy slope, A teen...           skis
# 1499  [A tennis ball and a woman with a racket on a ...  tennis racket
# 1500  [a man jumping skis at a ski area, A person wi...           skis
# 1501  [a large tower that has a big clock at top, Th...          clock
# 1502  [A woman standing on a tennis court holding a ...  tennis racket
#
#              file_name  img_id
# 0     000000236784.jpg  236784
# 1     000000360943.jpg  360943
# 2     000000464522.jpg  464522
# 3     000000409211.jpg  409211
# 4     000000301563.jpg  301563
# 5     000000063552.jpg   63552
# 6     000000385190.jpg  385190
# 7     000000173830.jpg  173830
# 8     000000174482.jpg  174482
# 9     000000343076.jpg  343076
# 10    000000273642.jpg  273642
# 11    000000079969.jpg   79969
# 12    000000058350.jpg   58350
# 13    000000445365.jpg  445365
# 14    000000065485.jpg   65485
# 15    000000544444.jpg  544444
# 16    000000151629.jpg  151629
# 17    000000065736.jpg   65736
# 18    000000379332.jpg  379332
# 19    000000313034.jpg  313034
# 20    000000349302.jpg  349302
# 21    000000577932.jpg  577932
# 22    000000292997.jpg  292997
# 23    000000437392.jpg  437392
# 24    000000413395.jpg  413395
# 25    000000563603.jpg  563603
# 26    000000055528.jpg   55528
# 27    000000350833.jpg  350833
# 28    000000153782.jpg  153782
# 29    000000162858.jpg  162858
# ...                ...     ...
# 1473  000000361103.jpg  361103
# 1474  000000366141.jpg  366141
# 1475  000000104803.jpg  104803
# 1476  000000249129.jpg  249129
# 1477  000000513283.jpg  513283
# 1478  000000288685.jpg  288685
# 1479  000000251572.jpg  251572
# 1480  000000131556.jpg  131556
# 1481  000000175387.jpg  175387
# 1482  000000530099.jpg  530099
# 1483  000000233139.jpg  233139
# 1484  000000093437.jpg   93437
# 1485  000000562581.jpg  562581
# 1486  000000203864.jpg  203864
# 1487  000000575815.jpg  575815
# 1488  000000323151.jpg  323151
# 1489  000000085682.jpg   85682
# 1490  000000540932.jpg  540932
# 1491  000000100582.jpg  100582
# 1492  000000331075.jpg  331075
# 1493  000000361238.jpg  361238
# 1494  000000353970.jpg  353970
# 1495  000000160012.jpg  160012
# 1496  000000314709.jpg  314709
# 1497  000000289059.jpg  289059
# 1498  000000573258.jpg  573258
# 1499  000000328430.jpg  328430
# 1500  000000249786.jpg  249786
# 1501  000000519522.jpg  519522
# 1502  000000161861.jpg  161861
#
# [1503 rows x 5 columns]

# %%
# connect all text to build a doc2vec vocabulary
df["captions"] = df["captions"].apply(lambda sents: " ".join(sents))
df["captions"][0]
# Out:
# 'two dogs laying down on a brown couch there are two large dogs sleeping on the couch a couple of dogs are laying on a coach Two black dogs on a couch sleeping peacefully. Two dogs are lying on the brown couch. '

# %%
from gensim.utils import simple_preprocess
df["words"] = df.apply(lambda row: simple_preprocess(row["captions"]), axis=1)
df["words"][0]
# Out:
# 2018-05-20 22:39:22,226 : INFO : 'pattern' package not found; tag filters are not available for English
# ['two',
#  'dogs',
#  'laying',
#  'down',
#  'on',
#  'brown',
#  'couch',
#  'there',
#  'are',
#  'two',
#  'large',
#  'dogs',
#  'sleeping',
#  'on',
#  'the',
#  'couch',
#  'couple',
#  'of',
#  'dogs',
#  'are',
#  'laying',
#  'on',
#  'coach',
#  'two',
#  'black',
#  'dogs',
#  'on',
#  'couch',
#  'sleeping',
#  'peacefully',
#  'two',
#  'dogs',
#  'are',
#  'lying',
#  'on',
#  'the',
#  'brown',
#  'couch']

# %%
from gensim.models import KeyedVectors
word2vec = KeyedVectors.load_word2vec_format('./data/GoogleNews-vectors-negative300.bin', binary=True, limit=200000)
# Out:
# 2018-05-20 22:39:22,439 : INFO : loading projection weights from ./data/GoogleNews-vectors-negative300.bin
# 2018-05-20 22:39:26,080 : INFO : loaded (200000, 300) matrix from ./data/GoogleNews-vectors-negative300.bin

# %%
def get_vectors(words):
    return list(map(lambda word: word2vec[word], filter(lambda word: word in word2vec, words)))

# %%
df["vectors"] = df.apply(lambda row: get_vectors(row["words"]), axis=1)

# %%
import numpy as np
df["vector_avg"] = df.apply(lambda row: np.divide(np.sum(row["vectors"], axis = 0), len(row["vectors"])), axis=1)
df[:5]
# Out:
#                                       all_categories  \
# 0                                  [dog, dog, couch]
# 1                                              [cat]
# 2                                         [dog, dog]
# 3  [sports ball, tennis racket, person, person, p...
# 4  [person, person, skis, backpack, person, skis,...
#
#                                             captions       category  \
# 0  two dogs laying down on a brown couch there ar...            dog
# 1  An orange cat sitting in front of a door to a ...            cat
# 2  A brown and white dog standing next to another...            dog
# 3  A man standing on a clay tennis court with a r...  tennis racket
# 4  A man riding skis down a snow covered slope. A...           skis
#
#           file_name  img_id  \
# 0  000000236784.jpg  236784
# 1  000000360943.jpg  360943
# 2  000000464522.jpg  464522
# 3  000000409211.jpg  409211
# 4  000000301563.jpg  301563
#
#                                                words  \
# 0  [two, dogs, laying, down, on, brown, couch, th...
# 1  [an, orange, cat, sitting, in, front, of, door...
# 2  [brown, and, white, dog, standing, next, to, a...
# 3  [man, standing, on, clay, tennis, court, with,...
# 4  [man, riding, skis, down, snow, covered, slope...
#
#                                              vectors  \
# 0  [[0.03173828, -0.10644531, 0.0024108887, 0.052...
# 1  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 2  [[0.007873535, 0.12890625, 0.02734375, 0.15234...
# 3  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 4  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
#
#                                           vector_avg
# 0  [0.052157015, -0.029487893, 0.027018366, 0.141...
# 1  [0.056553233, 0.026530873, 0.0018477007, 0.101...
# 2  [0.042373456, 0.04664853, -0.014217979, 0.1092...
# 3  [0.032073192, 0.036617965, 0.0736241, 0.019112...
# 4  [0.073890686, -0.0041534104, 0.07101864, 0.049...

# %%
# Model separates words with underscore

categories = list(map(lambda cat: cat.replace(" ", "_"), df["category"].unique()))
categories = list(map(lambda cat: cat if cat != 'traffic_light' else 'traffic', categories))
categories
# Out:
# ['dog',
#  'cat',
#  'tennis_racket',
#  'skis',
#  'traffic',
#  'pizza',
#  'giraffe',
#  'clock',
#  'toilet',
#  'surfboard']

# %%
# 1. Google's model does not contain phrase traffic light
# 2. Model separates words with underscore

def get_prediction(vector):
    similar_word_tuples = word2vec.similar_by_vector(vector)
    prediction = word2vec.most_similar_to_given(similar_word_tuples[0][0], categories)
    if (prediction == "traffic"):
        prediction = "traffic light"
    if (prediction == "tennis_racket"):
        prediction = "tennis racket"
    return prediction

# %%
df["similar"] = df.apply(lambda row: get_prediction(row["vector_avg"]), axis=1)
df[:5]
# Out:
# 2018-05-20 22:39:28,809 : INFO : precomputing L2-norms of word weight vectors
#                                       all_categories  \
# 0                                  [dog, dog, couch]
# 1                                              [cat]
# 2                                         [dog, dog]
# 3  [sports ball, tennis racket, person, person, p...
# 4  [person, person, skis, backpack, person, skis,...
#
#                                             captions       category  \
# 0  two dogs laying down on a brown couch there ar...            dog
# 1  An orange cat sitting in front of a door to a ...            cat
# 2  A brown and white dog standing next to another...            dog
# 3  A man standing on a clay tennis court with a r...  tennis racket
# 4  A man riding skis down a snow covered slope. A...           skis
#
#           file_name  img_id  \
# 0  000000236784.jpg  236784
# 1  000000360943.jpg  360943
# 2  000000464522.jpg  464522
# 3  000000409211.jpg  409211
# 4  000000301563.jpg  301563
#
#                                                words  \
# 0  [two, dogs, laying, down, on, brown, couch, th...
# 1  [an, orange, cat, sitting, in, front, of, door...
# 2  [brown, and, white, dog, standing, next, to, a...
# 3  [man, standing, on, clay, tennis, court, with,...
# 4  [man, riding, skis, down, snow, covered, slope...
#
#                                              vectors  \
# 0  [[0.03173828, -0.10644531, 0.0024108887, 0.052...
# 1  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 2  [[0.007873535, 0.12890625, 0.02734375, 0.15234...
# 3  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 4  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
#
#                                           vector_avg        similar
# 0  [0.052157015, -0.029487893, 0.027018366, 0.141...            dog
# 1  [0.056553233, 0.026530873, 0.0018477007, 0.101...            cat
# 2  [0.042373456, 0.04664853, -0.014217979, 0.1092...            dog
# 3  [0.032073192, 0.036617965, 0.0736241, 0.019112...  tennis racket
# 4  [0.073890686, -0.0041534104, 0.07101864, 0.049...           skis

# %% [markdown]
# ## Classification and testing

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %%
# Returns the mean accuracy on the given test data and labels, in 5 cross validation splits
scores = cross_val_score(classifier, 
                         pd.DataFrame(df["vector_avg"].tolist()), 
                         df["category"].values, 
                         cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.96 (+/- 0.02)

# %%
from sklearn.svm import LinearSVC
classifier = LinearSVC()

# %%
# Returns the mean accuracy on the given test data and labels, in 5 cross validation splits
scores = cross_val_score(classifier, 
                         pd.DataFrame(df["vector_avg"].tolist()), 
                         df["category"].values, 
                         cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.96 (+/- 0.02)

# %%
from sklearn.model_selection import cross_val_predict

df["predictions"] = cross_val_predict(classifier, 
                                      pd.DataFrame(df["vector_avg"].tolist()), 
                                      df["category"].values, 
                                      cv=5)
df[:5]
# Out:
#                                       all_categories  \
# 0                                  [dog, dog, couch]
# 1                                              [cat]
# 2                                         [dog, dog]
# 3  [sports ball, tennis racket, person, person, p...
# 4  [person, person, skis, backpack, person, skis,...
#
#                                             captions       category  \
# 0  two dogs laying down on a brown couch there ar...            dog
# 1  An orange cat sitting in front of a door to a ...            cat
# 2  A brown and white dog standing next to another...            dog
# 3  A man standing on a clay tennis court with a r...  tennis racket
# 4  A man riding skis down a snow covered slope. A...           skis
#
#           file_name  img_id  \
# 0  000000236784.jpg  236784
# 1  000000360943.jpg  360943
# 2  000000464522.jpg  464522
# 3  000000409211.jpg  409211
# 4  000000301563.jpg  301563
#
#                                                words  \
# 0  [two, dogs, laying, down, on, brown, couch, th...
# 1  [an, orange, cat, sitting, in, front, of, door...
# 2  [brown, and, white, dog, standing, next, to, a...
# 3  [man, standing, on, clay, tennis, court, with,...
# 4  [man, riding, skis, down, snow, covered, slope...
#
#                                              vectors  \
# 0  [[0.03173828, -0.10644531, 0.0024108887, 0.052...
# 1  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 2  [[0.007873535, 0.12890625, 0.02734375, 0.15234...
# 3  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 4  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
#
#                                           vector_avg        similar  \
# 0  [0.052157015, -0.029487893, 0.027018366, 0.141...            dog
# 1  [0.056553233, 0.026530873, 0.0018477007, 0.101...            cat
# 2  [0.042373456, 0.04664853, -0.014217979, 0.1092...            dog
# 3  [0.032073192, 0.036617965, 0.0736241, 0.019112...  tennis racket
# 4  [0.073890686, -0.0041534104, 0.07101864, 0.049...           skis
#
#      predictions
# 0            dog
# 1            cat
# 2            dog
# 3  tennis racket
# 4           skis

# %% [markdown]
# ## Misclassified

# %%
k1 = df.loc[(df.category != df.predictions)]
k1 = k1.sample(frac=1).reset_index(drop=True)
k1
# Out:
#                                        all_categories  \
# 0   [potted plant, refrigerator, chair, cup, cup, ...
# 1                            [person, remote, toilet]
# 2   [tv, tv, mouse, keyboard, person, person, pers...
# 3   [person, baseball bat, car, car, car, car, tra...
# 4   [cup, banana, cup, book, book, book, pizza, pi...
# 5   [bottle, bottle, bottle, bottle, person, tenni...
# 6   [dog, dog, chair, person, bed, book, book, boo...
# 7   [clock, person, hot dog, donut, donut, donut, ...
# 8   [bottle, clock, dining table, person, person, ...
# 9   [tv, cat, couch, chair, book, book, chair, boo...
# 10  [bottle, cup, laptop, laptop, laptop, mouse, k...
# 11  [bottle, bottle, bottle, car, car, traffic lig...
# 12  [tv, couch, person, person, clock, donut, book...
# 13  [cell phone, person, tennis racket, laptop, bo...
# 14                            [tv, cat, couch, chair]
# 15  [umbrella, umbrella, person, person, person, p...
# 16  [clock, person, person, person, person, person...
# 17  [bed, bed, person, toilet, backpack, bottle, b...
# 18  [car, person, frisbee, traffic light, traffic ...
# 19  [motorcycle, person, person, person, person, p...
# 20  [chair, person, wine glass, fork, knife, bowl,...
# 21  [umbrella, person, person, person, person, per...
# 22                       [surfboard, cake, surfboard]
# 23                      [horse, clock, clock, person]
# 24  [train, person, person, person, clock, person,...
# 25  [chair, chair, dining table, person, fork, for...
# 26  [couch, person, person, remote, remote, remote...
# 27  [dog, person, person, frisbee, kite, person, p...
# 28  [backpack, handbag, suitcase, suitcase, suitca...
# 29  [sandwich, car, chair, dining table, person, p...
# 30                      [dog, person, bench, bicycle]
# 31  [bicycle, train, person, tie, bench, bench, ba...
# 32         [dog, motorcycle, bicycle, bicycle, truck]
# 33  [dog, cow, cow, cow, cow, cow, cow, cow, cow, ...
# 34  [bottle, chair, chair, dining table, dining ta...
# 35  [cell phone, car, car, car, person, person, pe...
# 36  [dog, person, person, person, person, person, ...
# 37  [train, person, person, person, person, person...
# 38  [dog, boat, boat, person, person, person, pers...
# 39  [train, person, person, person, person, person...
# 40  [dog, person, person, boat, boat, boat, umbrel...
# 41  [potted plant, potted plant, potted plant, pot...
# 42                                     [train, clock]
# 43  [sandwich, clock, person, person, person, pers...
# 44  [person, person, person, skateboard, person, p...
# 45  [umbrella, tie, person, person, person, person...
# 46          [car, car, car, person, car, toilet, car]
# 47                       [person, cake, spoon, clock]
# 48  [bicycle, bicycle, bicycle, backpack, backpack...
# 49  [toilet, bowl, bowl, bowl, sink, sink, sink, v...
# 50  [dog, horse, person, person, person, person, b...
# 51  [cat, cat, person, bottle, cat, fire hydrant, ...
# 52  [bus, person, person, person, person, person, ...
# 53  [bottle, bottle, bottle, bottle, bottle, perso...
# 54                         [boat, boat, clock, clock]
# 55  [kite, kite, person, dog, person, person, pers...
# 56                 [bird, giraffe, cow, potted plant]
#
#                                              captions       category  \
# 0   A smaller kitchen with a very decorated fridge...      surfboard
# 1   A man holding holding a giant remote control. ...         toilet
# 2   The computer monitor has a framed picture near...            cat
# 3   Kid poses for a picture in a baseball uniform ...  traffic light
# 4   A variety of items is shown in a shopping cart...          pizza
# 5   The man holds a ping pong paddle under the she...  tennis racket
# 6   A man sitting at a computer desk in front of a...            dog
# 7   This a case full of doughnuts and cinnamon bun...          clock
# 8   A group of people sitting around a wooden tabl...          clock
# 9   A living room filled with furniture and a flat...            cat
# 10  Three laptop computers and a desktop computer ...          clock
# 11  a man standing in front of the grill of a  hot...  traffic light
# 12  A little boy is being held on a lap while eati...          clock
# 13  there is a tennis racket and a laptop on the f...  tennis racket
# 14  a cat laying on top of a chair in the living r...            cat
# 15  A group of people standing and sitting on top ...            dog
# 16  Two children standing near wrought iron fence ...          clock
# 17  A young woman using a laptop computer while si...         toilet
# 18  A girl is playing in a grassy area. a woman on...  traffic light
# 19  A street scene with a person on a motorcycle. ...            dog
# 20  An individual is capture in the stillness of t...          pizza
# 21  A woman in a bikini laying under a red umbrell...      surfboard
# 22  Advertising photograph of a surf-themed birthd...      surfboard
# 23  A woman exercising a brown horse in a riding r...          clock
# 24  A passenger train is sitting at a station. A t...          clock
# 25  A boy getting ready to blow out candles on a b...          pizza
# 26  A couple of women holding game controllers in ...            dog
# 27  people on a gold course enjoy a few games  A p...            dog
# 28  A crowded airport filled with people carrying ...          clock
# 29  A man taking a picture of plates of food. a ma...          clock
# 30  A man is riding a large bike through the park....            dog
# 31  the man is working on his laptop while he wait...  traffic light
# 32  a small motor bike outside of the garage A tri...            dog
# 33  A bunch of cows that are standing in the grass...            dog
# 34  The two teens are playing video games in the r...          pizza
# 35  A man is taking a photo of a city with his pho...  traffic light
# 36  a person riding a skate board on a city street...            dog
# 37  a red train is docked at the station Several p...          clock
# 38  Sail boats sail over a body of water while peo...            dog
# 39  A train in its full span gives the illusion of...          clock
# 40  Man and woman with umbrella hats sitting on to...            dog
# 41  A cat in front of a wooden bench in a garden. ...            cat
# 42  A high speed train is seen in the station. A t...          clock
# 43  a close up of a person holding up a plate of f...          clock
# 44  A young man riding a skateboard with an older ...      surfboard
# 45  A newly married couple walking down a street. ...  traffic light
# 46  A young attractive woman sitting on a toilette...         toilet
# 47  A woman with glasses eating a piece of cake. a...          clock
# 48  a gathering outside on the lawn of city hall A...          pizza
# 49  Ten porcelain pieces with floral patterns pain...         toilet
# 50  A horse pulling  carriage travels through a bu...            dog
# 51  A woman in yellow shirt and skirt with cats in...            cat
# 52  A black and white image with a colored british...          clock
# 53  a man and woman standing side by side in a kit...          pizza
# 54  The ferris wheel is located in the middle of t...          clock
# 55  many people on a beach with a kite flying in t...            dog
# 56  Set of toy animals sitting in front of a red w...        giraffe
#
#            file_name  img_id  \
# 0   000000407614.jpg  407614
# 1   000000037670.jpg   37670
# 2   000000149222.jpg  149222
# 3   000000491464.jpg  491464
# 4   000000535253.jpg  535253
# 5   000000112298.jpg  112298
# 6   000000366884.jpg  366884
# 7   000000405195.jpg  405195
# 8   000000009590.jpg    9590
# 9   000000139684.jpg  139684
# 10  000000097994.jpg   97994
# 11  000000213255.jpg  213255
# 12  000000084674.jpg   84674
# 13  000000035279.jpg   35279
# 14  000000366141.jpg  366141
# 15  000000143961.jpg  143961
# 16  000000505789.jpg  505789
# 17  000000393569.jpg  393569
# 18  000000442746.jpg  442746
# 19  000000139099.jpg  139099
# 20  000000425361.jpg  425361
# 21  000000262048.jpg  262048
# 22  000000092177.jpg   92177
# 23  000000015956.jpg   15956
# 24  000000369675.jpg  369675
# 25  000000180101.jpg  180101
# 26  000000371749.jpg  371749
# 27  000000471789.jpg  471789
# 28  000000084270.jpg   84270
# 29  000000350148.jpg  350148
# 30  000000289343.jpg  289343
# 31  000000076547.jpg   76547
# 32  000000007386.jpg    7386
# 33  000000415990.jpg  415990
# 34  000000091500.jpg   91500
# 35  000000545100.jpg  545100
# 36  000000279278.jpg  279278
# 37  000000146825.jpg  146825
# 38  000000078565.jpg   78565
# 39  000000508917.jpg  508917
# 40  000000534270.jpg  534270
# 41  000000279145.jpg  279145
# 42  000000159684.jpg  159684
# 43  000000045550.jpg   45550
# 44  000000087476.jpg   87476
# 45  000000496854.jpg  496854
# 46  000000365642.jpg  365642
# 47  000000327592.jpg  327592
# 48  000000507037.jpg  507037
# 49  000000571804.jpg  571804
# 50  000000463522.jpg  463522
# 51  000000375493.jpg  375493
# 52  000000233771.jpg  233771
# 53  000000520264.jpg  520264
# 54  000000506004.jpg  506004
# 55  000000057760.jpg   57760
# 56  000000289393.jpg  289393
#
#                                                 words  \
# 0   [smaller, kitchen, with, very, decorated, frid...
# 1   [man, holding, holding, giant, remote, control...
# 2   [the, computer, monitor, has, framed, picture,...
# 3   [kid, poses, for, picture, in, baseball, unifo...
# 4   [variety, of, items, is, shown, in, shopping, ...
# 5   [the, man, holds, ping, pong, paddle, under, t...
# 6   [man, sitting, at, computer, desk, in, front, ...
# 7   [this, case, full, of, doughnuts, and, cinnamo...
# 8   [group, of, people, sitting, around, wooden, t...
# 9   [living, room, filled, with, furniture, and, f...
# 10  [three, laptop, computers, and, desktop, compu...
# 11  [man, standing, in, front, of, the, grill, of,...
# 12  [little, boy, is, being, held, on, lap, while,...
# 13  [there, is, tennis, racket, and, laptop, on, t...
# 14  [cat, laying, on, top, of, chair, in, the, liv...
# 15  [group, of, people, standing, and, sitting, on...
# 16  [two, children, standing, near, wrought, iron,...
# 17  [young, woman, using, laptop, computer, while,...
# 18  [girl, is, playing, in, grassy, area, woman, o...
# 19  [street, scene, with, person, on, motorcycle, ...
# 20  [an, individual, is, capture, in, the, stillne...
# 21  [woman, in, bikini, laying, under, red, umbrel...
# 22  [advertising, photograph, of, surf, themed, bi...
# 23  [woman, exercising, brown, horse, in, riding, ...
# 24  [passenger, train, is, sitting, at, station, t...
# 25  [boy, getting, ready, to, blow, out, candles, ...
# 26  [couple, of, women, holding, game, controllers...
# 27  [people, on, gold, course, enjoy, few, games, ...
# 28  [crowded, airport, filled, with, people, carry...
# 29  [man, taking, picture, of, plates, of, food, m...
# 30  [man, is, riding, large, bike, through, the, p...
# 31  [the, man, is, working, on, his, laptop, while...
# 32  [small, motor, bike, outside, of, the, garage,...
# 33  [bunch, of, cows, that, are, standing, in, the...
# 34  [the, two, teens, are, playing, video, games, ...
# 35  [man, is, taking, photo, of, city, with, his, ...
# 36  [person, riding, skate, board, on, city, stree...
# 37  [red, train, is, docked, at, the, station, sev...
# 38  [sail, boats, sail, over, body, of, water, whi...
# 39  [train, in, its, full, span, gives, the, illus...
# 40  [man, and, woman, with, umbrella, hats, sittin...
# 41  [cat, in, front, of, wooden, bench, in, garden...
# 42  [high, speed, train, is, seen, in, the, statio...
# 43  [close, up, of, person, holding, up, plate, of...
# 44  [young, man, riding, skateboard, with, an, old...
# 45  [newly, married, couple, walking, down, street...
# 46  [young, attractive, woman, sitting, on, toilet...
# 47  [woman, with, glasses, eating, piece, of, cake...
# 48  [gathering, outside, on, the, lawn, of, city, ...
# 49  [ten, porcelain, pieces, with, floral, pattern...
# 50  [horse, pulling, carriage, travels, through, b...
# 51  [woman, in, yellow, shirt, and, skirt, with, c...
# 52  [black, and, white, image, with, colored, brit...
# 53  [man, and, woman, standing, side, by, side, in...
# 54  [the, ferris, wheel, is, located, in, the, mid...
# 55  [many, people, on, beach, with, kite, flying, ...
# 56  [set, of, toy, animals, sitting, in, front, of...
#
#                                               vectors  \
# 0   [[-0.050048828, 0.034179688, -0.0703125, 0.175...
# 1   [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 2   [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 3   [[0.18457031, 0.14941406, 0.09082031, 0.310546...
# 4   [[0.030639648, 0.09277344, -0.2578125, 0.07470...
# 5   [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 6   [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 7   [[0.109375, 0.140625, -0.03173828, 0.16601562,...
# 8   [[-0.021972656, 0.015197754, -0.029907227, 0.0...
# 9   [[0.1328125, 0.10644531, -0.07763672, 0.182617...
# 10  [[0.049316406, -0.100097656, 0.006652832, 0.05...
# 11  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 12  [[0.18945312, 0.13671875, -0.09472656, 0.24218...
# 13  [[0.09423828, -0.022827148, 0.052246094, 0.026...
# 14  [[0.012329102, 0.20410156, -0.28515625, 0.2167...
# 15  [[-0.021972656, 0.015197754, -0.029907227, 0.0...
# 16  [[0.03173828, -0.10644531, 0.0024108887, 0.052...
# 17  [[0.09472656, 0.328125, -0.048583984, -0.00665...
# 18  [[0.13867188, 0.0037384033, 0.064453125, -0.07...
# 19  [[0.09814453, 0.075683594, 0.030883789, 0.1787...
# 20  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 21  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 22  [[0.390625, -0.3046875, -0.3046875, 0.09912109...
# 23  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 24  [[0.51171875, -0.06347656, 0.23242188, 0.00891...
# 25  [[0.23535156, 0.16503906, 0.09326172, -0.12890...
# 26  [[0.09667969, -0.0032653809, -0.37109375, 0.10...
# 27  [[0.26367188, -0.019165039, 0.028930664, 0.234...
# 28  [[0.01940918, 0.16992188, -0.21386719, 0.13574...
# 29  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 30  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 31  [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 32  [[0.15917969, 0.095703125, -0.125, 0.10253906,...
# 33  [[0.05419922, 0.1953125, -0.010986328, 0.28125...
# 34  [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 35  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 36  [[0.27539062, -0.24707031, 0.017211914, 0.1679...
# 37  [[0.09716797, -0.08496094, 0.27148438, 0.22167...
# 38  [[0.22363281, 0.43359375, -0.20117188, -0.0125...
# 39  [[-0.0027160645, 0.23242188, 0.057861328, -0.0...
# 40  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 41  [[0.012329102, 0.20410156, -0.28515625, 0.2167...
# 42  [[0.076660156, 0.00970459, -0.080078125, 0.181...
# 43  [[-0.0032043457, -0.07080078, 0.08984375, 0.21...
# 44  [[0.09472656, 0.328125, -0.048583984, -0.00665...
# 45  [[-0.044189453, -0.123046875, 0.12597656, -0.1...
# 46  [[0.09472656, 0.328125, -0.048583984, -0.00665...
# 47  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 48  [[0.14550781, 0.16503906, 0.049804688, 0.09619...
# 49  [[0.0058898926, -0.09814453, 0.028320312, 0.20...
# 50  [[0.0005340576, 0.03112793, 0.0050354004, -0.0...
# 51  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 52  [[0.10498047, 0.018432617, 0.008972168, -0.012...
# 53  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 54  [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 55  [[0.19335938, -0.004333496, -0.032226562, 0.13...
# 56  [[0.029541016, 0.25976562, 0.19335938, 0.08837...
#
#                                            vector_avg        similar  \
# 0   [-0.055013802, 0.08017437, -0.016232222, 0.078...         toilet
# 1   [0.08915138, 0.024242401, -0.038812637, 0.0623...         toilet
# 2   [0.027858611, -0.044955898, -0.05519055, 0.043...  tennis racket
# 3   [-0.00027678732, 0.15596612, 0.07994754, 0.023...  tennis racket
# 4   [0.048654344, 0.058258295, -0.09881677, 0.1640...            dog
# 5   [0.02190986, 0.010273273, 0.013679749, 0.07203...            dog
# 6   [0.06266062, 0.044794988, 0.0012399774, 0.0781...         toilet
# 7   [-0.00797035, 0.025007578, -0.049233273, 0.186...          pizza
# 8   [0.0048433193, 0.03782205, 0.031207366, 0.1744...         toilet
# 9   [0.037010524, 0.058023203, 0.00876294, 0.11404...         toilet
# 10  [0.07563612, -0.08315701, -0.0049557155, 0.129...         toilet
# 11  [0.051148526, 0.07332452, 0.021673867, 0.12197...          pizza
# 12  [0.051161025, 0.043923102, 0.034996543, 0.0655...        giraffe
# 13  [0.076261654, 0.013311341, 0.056695893, 0.0601...          clock
# 14  [0.05642935, 0.0016420316, 0.01592284, 0.12165...      surfboard
# 15  [0.052807618, 0.026527405, 0.03807373, 0.12752...          clock
# 16  [0.0136366105, 0.069122314, 0.014968533, 0.065...            dog
# 17  [0.06295634, -0.0036450764, 0.04265364, 0.0957...         toilet
# 18  [0.11844532, 0.06442096, 0.055497248, 0.048981...  tennis racket
# 19  [0.08060455, -0.013256497, -0.0058034263, 0.10...            dog
# 20  [0.01859116, 0.051346943, -0.02416192, 0.06112...          pizza
# 21  [0.07131813, -0.039345514, 0.066478185, 0.0639...      surfboard
# 22  [-0.0021552192, 0.026490806, -0.012543742, 0.1...          pizza
# 23  [0.063723974, 0.03292411, 0.0018511091, 0.0037...            dog
# 24  [0.056766763, 0.06975282, 0.06623925, 0.064160...         toilet
# 25  [0.10837446, 0.03699203, 0.056565057, 0.085981...          pizza
# 26  [0.045386273, 0.032844212, 0.012589662, 0.0735...          clock
# 27  [0.06650337, 0.04913495, -0.020373577, 0.10593...  traffic light
# 28  [0.08989343, 0.055334758, -0.03154169, 0.12995...  traffic light
# 29  [0.036826324, 0.09107259, 0.014297994, 0.10852...          pizza
# 30  [0.10161656, 0.008689662, 0.009137834, 0.10111...           skis
# 31  [0.05719968, 0.044478722, 0.0673893, 0.0495332...            dog
# 32  [0.060295336, 0.03913648, -0.00091645215, 0.03...         toilet
# 33  [0.05001028, 0.06538954, 0.020808972, 0.065958...        giraffe
# 34  [0.052502442, 0.026852757, 0.04134674, 0.09458...  tennis racket
# 35  [0.053505316, 0.078639336, 0.008547899, -0.021...            dog
# 36  [0.09721039, 0.010206269, 0.04754341, 0.113809...  traffic light
# 37  [0.025868734, 0.06388033, 0.059446678, 0.04288...         toilet
# 38  [0.09650697, 0.10090093, -0.051098112, 0.06210...      surfboard
# 39  [0.047171243, 0.068506755, 0.05275894, 0.04697...         toilet
# 40  [0.018541971, 0.00088773173, -0.027387619, 0.0...          clock
# 41  [0.09951285, 0.13124688, 0.07675313, 0.1154907...         toilet
# 42  [0.009081041, 0.10517677, 0.064845726, 0.04908...         toilet
# 43  [-0.0018467759, 0.060885344, 0.030042706, 0.14...          pizza
# 44  [0.11482043, 0.013994266, 0.047851365, 0.08769...      surfboard
# 45  [0.040103912, -0.025392914, -0.01187439, 0.012...        giraffe
# 46  [0.09142665, 0.007317794, -0.00028429533, 0.10...         toilet
# 47  [-0.0062092626, 0.0034012462, 0.013139415, 0.1...          pizza
# 48  [-0.0017282587, 0.03427124, 0.049038135, 0.110...          pizza
# 49  [-0.025797525, 0.09048971, 0.0127682155, 0.132...         toilet
# 50  [0.05004548, 0.059888374, 0.023850603, 0.06431...            dog
# 51  [0.07454224, 0.03916931, 0.02020874, 0.0478256...  traffic light
# 52  [0.032677915, 0.05935474, 0.038118403, 0.08287...            cat
# 53  [0.05921444, 0.03323315, 0.016690655, 0.036396...            dog
# 54  [0.058732685, 0.044355243, 0.07181991, 0.02813...          clock
# 55  [0.09510597, 0.01770999, -0.02956081, 0.091790...      surfboard
# 56  [0.08370209, 0.081186995, -0.040471327, 0.1330...            dog
#
#       predictions
# 0           clock
# 1           clock
# 2           clock
# 3   tennis racket
# 4           clock
# 5           clock
# 6           clock
# 7           pizza
# 8           pizza
# 9           clock
# 10         toilet
# 11            dog
# 12          pizza
# 13          clock
# 14          clock
# 15          clock
# 16  traffic light
# 17          clock
# 18            dog
# 19  traffic light
# 20          clock
# 21  traffic light
# 22          clock
# 23            dog
# 24  traffic light
# 25          clock
# 26          clock
# 27           skis
# 28  traffic light
# 29          pizza
# 30  traffic light
# 31          clock
# 32  traffic light
# 33        giraffe
# 34          clock
# 35          clock
# 36  traffic light
# 37  traffic light
# 38      surfboard
# 39  traffic light
# 40  traffic light
# 41          clock
# 42  traffic light
# 43          pizza
# 44  traffic light
# 45          clock
# 46  traffic light
# 47          pizza
# 48          clock
# 49          clock
# 50  traffic light
# 51  traffic light
# 52  traffic light
# 53          clock
# 54      surfboard
# 55      surfboard
# 56            dog
