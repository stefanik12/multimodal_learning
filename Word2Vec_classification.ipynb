# %% [markdown]
# ## Word2Vec unimodal classification demo
#
# 1. Vectorize words from captions
#
# 2. Calculate vectors average
#
# 3. Find most similar word to the average vector
#
# 3. Use one or two distinct classifiers to perform the classification
#
# 4. Compute the accuracy of classification with the selected classifiers (LogReg, SVC)

# %%
import pandas as pd

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
df = pd.read_json("data/COCO/coco-easier.txt", 
                  lines=True)
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#                                          all_categories  \
# 0     [bus, person, person, person, person, car, car...
# 1     [person, person, person, person, person, perso...
# 2                     [person, giraffe, person, person]
# 3     [bottle, refrigerator, oven, spoon, spoon, bot...
# 4     [car, car, car, car, car, car, traffic light, ...
# 5     [toilet, toilet, toilet, toilet, toilet, toile...
# 6                                        [dog, frisbee]
# 7                                              [toilet]
# 8     [bottle, bottle, bottle, bottle, bottle, bottl...
# 9                                   [person, surfboard]
# 10                  [dog, dog, handbag, person, person]
# 11    [bicycle, bicycle, traffic light, traffic ligh...
# 12                                     [zebra, giraffe]
# 13    [bottle, person, person, person, person, wine ...
# 14                                                [cat]
# 15    [car, car, car, car, traffic light, traffic li...
# 16                                             [toilet]
# 17                          [dog, horse, horse, person]
# 18                                  [surfboard, person]
# 19    [dog, person, person, person, person, person, ...
# 20    [bicycle, car, person, person, person, person,...
# 21                      [person, tennis racket, person]
# 22                                       [bench, clock]
# 23    [dog, boat, boat, person, person, person, pers...
# 24                                              [pizza]
# 25                                      [traffic light]
# 26                                              [clock]
# 27               [dog, tv, person, couch, dining table]
# 28    [traffic light, traffic light, traffic light, ...
# 29    [motorcycle, motorcycle, train, traffic light,...
# ...                                                 ...
# 1473                            [person, tennis racket]
# 1474  [bottle, bottle, person, person, cup, cup, kni...
# 1475                                            [pizza]
# 1476                             [toilet, sink, bottle]
# 1477  [backpack, handbag, suitcase, suitcase, suitca...
# 1478  [person, person, person, surfboard, person, pe...
# 1479                                [surfboard, person]
# 1480  [chair, dining table, person, cup, cup, pizza,...
# 1481  [car, car, car, traffic light, traffic light, ...
# 1482                                 [giraffe, giraffe]
# 1483               [giraffe, giraffe, giraffe, giraffe]
# 1484                             [person, skis, person]
# 1485  [sports ball, person, tennis racket, sports ba...
# 1486  [clock, clock, person, bench, bench, person, p...
# 1487  [chair, chair, chair, dining table, dining tab...
# 1488  [dining table, person, cup, fork, cup, cup, kn...
# 1489                                      [dog, person]
# 1490                                      [cat, laptop]
# 1491                                            [clock]
# 1492  [bus, bus, bus, person, person, person, person...
# 1493  [giraffe, giraffe, giraffe, giraffe, giraffe, ...
# 1494                                          [giraffe]
# 1495                                 [cat, bed, laptop]
# 1496  [person, tennis racket, person, person, person...
# 1497                          [cat, car, car, car, car]
# 1498                                     [clock, clock]
# 1499  [dog, sheep, sheep, sheep, sheep, person, pers...
# 1500                       [bottle, clock, oven, chair]
# 1501                                            [clock]
# 1502  [sports ball, car, car, car, person, tennis ra...
#
#                                                captions       category  \
# 0     [A city street show cars going up and down the...  traffic light
# 1     [Woman in wet suit considers waves near forest...      surfboard
# 2     [A giraffe stands alone outdoors at the zoo., ...        giraffe
# 3     [An oven with a stove, pots and utensils, and ...          clock
# 4     [A post office box is on the side of a busy st...  traffic light
# 5     [A row of white toilets sitting on top of a di...         toilet
# 6     [A dog that is jumping in the air looking at a...            dog
# 7     [A table with a plate of food and a urinal bas...         toilet
# 8     [A woman holding a small cake with lit candles...          clock
# 9     [A man in shorts surfing in the ocean, A man i...      surfboard
# 10    [Girl bending down with hand bag on her should...            dog
# 11    [A city sidewalk with people walking up and do...  traffic light
# 12    [a zebra and a giraffe stand next to each othe...        giraffe
# 13    [A beautiful woman sitting at a table with two...          pizza
# 14    [A cat wearing a hat while resting it's paws o...            cat
# 15    [Street sign painted on a road that looks like...  traffic light
# 16    [a man standing in front of a toilet taking a ...         toilet
# 17    [Two horses plowing the land as a man directs ...            dog
# 18    [a person riding a surf board on a wave, A per...      surfboard
# 19    [A black dog standing between people in line, ...            dog
# 20    [Many electronic wires pass over the road with...  traffic light
# 21    [A man in yellow shirt and black shorts playin...  tennis racket
# 22    [A long stone wall at a church with a cemetary...          clock
# 23    [Sail boats sail over a body of water while pe...            dog
# 24    [pizza sitting on stack of plates on wood back...          pizza
# 25    [Signs proclaim the famous Haight Ashbury inte...  traffic light
# 26    [A clock tower is part of an old building., We...          clock
# 27    [A dog sitting between its masters feet on a f...            dog
# 28    [A street light that shows, horse crossing on ...  traffic light
# 29    [A long train traveling down a city street wit...  traffic light
# ...                                                 ...            ...
# 1473  [A woman standing on a tennis court holding a ...  tennis racket
# 1474  [A woman prepares a pizza while a man watches....          pizza
# 1475  [A cracker is on a plate next to some mint., a...          pizza
# 1476  [A bathroom with a white toilet and a sink net...         toilet
# 1477  [A crowded airport filled with people carrying...          clock
# 1478  [Two people standing on a beach next to the oc...      surfboard
# 1479  [A woman in a bikini riding a wave on a surfbo...      surfboard
# 1480  [two young boys are enjoying pizza and pepsi, ...          pizza
# 1481  [There is very little traffic at this city int...  traffic light
# 1482  [two giraffes are standing together outside a ...        giraffe
# 1483  [A group of three giraffe standing next to eac...        giraffe
# 1484  [The woman wearing skis and a helmet is standi...           skis
# 1485  [A man holding a tennis racquet on a tennis co...  tennis racket
# 1486  [A large clock tower in front of a building ne...          clock
# 1487  [A man and a woman holding up a pizza in a sea...          pizza
# 1488  [A small pizza in the middle of a table., Some...          pizza
# 1489  [A man holding a small white dog while wearing...            dog
# 1490  [A cat sitting by a laptop but staring at a pe...            cat
# 1491  [A watch set to 12:25 sits on the table. , A c...          clock
# 1492  [A blue bus driving down a city street., A lar...  traffic light
# 1493  [A herd of giraffe running across a field., A ...        giraffe
# 1494  [A giraffe standing under a leaf filled tree.,...        giraffe
# 1495  [A brown, white and black cat looking at a lap...            cat
# 1496  [a tennis player stretching to hit a tennis ba...  tennis racket
# 1497  [The striped cat is sitting on top of the car....            cat
# 1498  [An old church building with clocks built into...          clock
# 1499  [a sheep in a field with a dog and people watc...            dog
# 1500  [A crowded kitchen that is cluttered and messy...          clock
# 1501  [A white clock tower at the top of a tiled bui...          clock
# 1502  [A man walking across a dirt field next to a s...  tennis racket
#
#              file_name  img_id
# 0     000000350023.jpg  350023
# 1     000000059635.jpg   59635
# 2     000000471567.jpg  471567
# 3     000000384661.jpg  384661
# 4     000000496722.jpg  496722
# 5     000000458054.jpg  458054
# 6     000000575357.jpg  575357
# 7     000000325114.jpg  325114
# 8     000000213547.jpg  213547
# 9     000000364126.jpg  364126
# 10    000000246454.jpg  246454
# 11    000000361103.jpg  361103
# 12    000000433243.jpg  433243
# 13    000000336356.jpg  336356
# 14    000000089271.jpg   89271
# 15    000000295809.jpg  295809
# 16    000000005503.jpg    5503
# 17    000000560880.jpg  560880
# 18    000000437331.jpg  437331
# 19    000000554002.jpg  554002
# 20    000000309391.jpg  309391
# 21    000000323895.jpg  323895
# 22    000000120572.jpg  120572
# 23    000000078565.jpg   78565
# 24    000000451693.jpg  451693
# 25    000000088218.jpg   88218
# 26    000000247806.jpg  247806
# 27    000000482917.jpg  482917
# 28    000000289222.jpg  289222
# 29    000000306893.jpg  306893
# ...                ...     ...
# 1473  000000161861.jpg  161861
# 1474  000000287347.jpg  287347
# 1475  000000522156.jpg  522156
# 1476  000000092124.jpg   92124
# 1477  000000084270.jpg   84270
# 1478  000000403584.jpg  403584
# 1479  000000356505.jpg  356505
# 1480  000000201426.jpg  201426
# 1481  000000221754.jpg  221754
# 1482  000000153299.jpg  153299
# 1483  000000286849.jpg  286849
# 1484  000000327605.jpg  327605
# 1485  000000205105.jpg  205105
# 1486  000000173057.jpg  173057
# 1487  000000491008.jpg  491008
# 1488  000000276285.jpg  276285
# 1489  000000236166.jpg  236166
# 1490  000000312213.jpg  312213
# 1491  000000468233.jpg  468233
# 1492  000000133819.jpg  133819
# 1493  000000450758.jpg  450758
# 1494  000000223130.jpg  223130
# 1495  000000115885.jpg  115885
# 1496  000000119995.jpg  119995
# 1497  000000466156.jpg  466156
# 1498  000000130465.jpg  130465
# 1499  000000288685.jpg  288685
# 1500  000000447169.jpg  447169
# 1501  000000028285.jpg   28285
# 1502  000000504415.jpg  504415
#
# [1503 rows x 5 columns]

# %%
# connect all text to build a doc2vec vocabulary
df["captions"] = df["captions"].apply(lambda sents: " ".join(sents))
df["captions"][0]
# Out:
# 'A city street show cars going up and down the hill. A hill of a street at a stoplight with traffic  A street that has four lanes of traffic. a long road with cars on both sides of it  A busy intersection in a city features several cars and buildings.'

# %%
from gensim.utils import simple_preprocess
df["words"] = df.apply(lambda row: simple_preprocess(row["captions"]), axis=1)
df["words"][0]
# Out:
# 2018-05-21 18:42:06,525 : INFO : 'pattern' package not found; tag filters are not available for English
# ['city',
#  'street',
#  'show',
#  'cars',
#  'going',
#  'up',
#  'and',
#  'down',
#  'the',
#  'hill',
#  'hill',
#  'of',
#  'street',
#  'at',
#  'stoplight',
#  'with',
#  'traffic',
#  'street',
#  'that',
#  'has',
#  'four',
#  'lanes',
#  'of',
#  'traffic',
#  'long',
#  'road',
#  'with',
#  'cars',
#  'on',
#  'both',
#  'sides',
#  'of',
#  'it',
#  'busy',
#  'intersection',
#  'in',
#  'city',
#  'features',
#  'several',
#  'cars',
#  'and',
#  'buildings']

# %%
from gensim.models import KeyedVectors
word2vec = KeyedVectors.load_word2vec_format('./data/GoogleNews-vectors-negative300.bin', binary=True, limit=200000)
# Out:
# 2018-05-21 18:42:06,705 : INFO : loading projection weights from ./data/GoogleNews-vectors-negative300.bin
# 2018-05-21 18:42:09,911 : INFO : loaded (200000, 300) matrix from ./data/GoogleNews-vectors-negative300.bin

# %%
def get_vectors(words):
    return list(map(lambda word: word2vec[word], filter(lambda word: word in word2vec, words)))

# %%
df["vectors"] = df.apply(lambda row: get_vectors(row["words"]), axis=1)

# %%
import numpy as np
df["vector_avg"] = df.apply(lambda row: np.divide(np.sum(row["vectors"], axis = 0), len(row["vectors"])), axis=1)
df[:5]
# Out:
#                                       all_categories  \
# 0  [bus, person, person, person, person, car, car...
# 1  [person, person, person, person, person, perso...
# 2                  [person, giraffe, person, person]
# 3  [bottle, refrigerator, oven, spoon, spoon, bot...
# 4  [car, car, car, car, car, car, traffic light, ...
#
#                                             captions       category  \
# 0  A city street show cars going up and down the ...  traffic light
# 1  Woman in wet suit considers waves near foreste...      surfboard
# 2  A giraffe stands alone outdoors at the zoo. A ...        giraffe
# 3  An oven with a stove, pots and utensils, and a...          clock
# 4  A post office box is on the side of a busy str...  traffic light
#
#           file_name  img_id  \
# 0  000000350023.jpg  350023
# 1  000000059635.jpg   59635
# 2  000000471567.jpg  471567
# 3  000000384661.jpg  384661
# 4  000000496722.jpg  496722
#
#                                                words  \
# 0  [city, street, show, cars, going, up, and, dow...
# 1  [woman, in, wet, suit, considers, waves, near,...
# 2  [giraffe, stands, alone, outdoors, at, the, zo...
# 3  [an, oven, with, stove, pots, and, utensils, a...
# 4  [post, office, box, is, on, the, side, of, bus...
#
#                                              vectors  \
# 0  [[-0.010070801, 0.057373047, 0.18359375, -0.04...
# 1  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 2  [[-0.055908203, 0.33007812, -0.39648438, 0.017...
# 3  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 4  [[-0.021484375, -0.0037994385, -0.114746094, -...
#
#                                           vector_avg
# 0  [0.07995111, 0.07051823, 0.06434508, 0.0843439...
# 1  [0.04933966, 0.012969971, -0.029572986, 0.0616...
# 2  [0.032204077, 0.088930055, -0.049434863, 0.037...
# 3  [-0.02268982, 0.087446496, 0.03933277, 0.06695...
# 4  [0.04842315, 0.0264707, -0.008286966, 0.109912...

# %%
# Model separates words with underscore

categories = list(map(lambda cat: cat.replace(" ", "_"), df["category"].unique()))
categories = list(map(lambda cat: cat if cat != 'traffic_light' else 'traffic', categories))
categories
# Out:
# ['traffic',
#  'surfboard',
#  'giraffe',
#  'clock',
#  'toilet',
#  'dog',
#  'pizza',
#  'cat',
#  'tennis_racket',
#  'skis']

# %%
# 1. Google's model does not contain phrase traffic light
# 2. Model separates words with underscore
# Tested accuracy was 0.72
def get_prediction_by_most_similar_word(vector):
    similar_word_tuples = word2vec.similar_by_vector(vector)
    prediction = word2vec.most_similar_to_given(similar_word_tuples[0][0], categories)
    if (prediction == "traffic"):
        prediction = "traffic light"
    if (prediction == "tennis_racket"):
        prediction = "tennis racket"
    return prediction

# %%
from scipy.spatial.distance import cosine
def get_prediction_by_cosine_sim(vector):
    prediction = categories[0]
    max_sim = 1;
    for cat in categories:
        similarity = cosine(vector, word2vec[cat])
        similarity
        if similarity < max_sim:
            prediction = cat
            max_sim = similarity
    if (prediction == "traffic"):
        prediction = "traffic light"
    if (prediction == "tennis_racket"):
        prediction = "tennis racket"
    return prediction

# %%
df["similar"] = df.apply(lambda row: get_prediction_by_cosine_sim(row["vector_avg"]), axis=1)
df[:5]
# Out:
#                                       all_categories  \
# 0  [bus, person, person, person, person, car, car...
# 1  [person, person, person, person, person, perso...
# 2                  [person, giraffe, person, person]
# 3  [bottle, refrigerator, oven, spoon, spoon, bot...
# 4  [car, car, car, car, car, car, traffic light, ...
#
#                                             captions       category  \
# 0  A city street show cars going up and down the ...  traffic light
# 1  Woman in wet suit considers waves near foreste...      surfboard
# 2  A giraffe stands alone outdoors at the zoo. A ...        giraffe
# 3  An oven with a stove, pots and utensils, and a...          clock
# 4  A post office box is on the side of a busy str...  traffic light
#
#           file_name  img_id  \
# 0  000000350023.jpg  350023
# 1  000000059635.jpg   59635
# 2  000000471567.jpg  471567
# 3  000000384661.jpg  384661
# 4  000000496722.jpg  496722
#
#                                                words  \
# 0  [city, street, show, cars, going, up, and, dow...
# 1  [woman, in, wet, suit, considers, waves, near,...
# 2  [giraffe, stands, alone, outdoors, at, the, zo...
# 3  [an, oven, with, stove, pots, and, utensils, a...
# 4  [post, office, box, is, on, the, side, of, bus...
#
#                                              vectors  \
# 0  [[-0.010070801, 0.057373047, 0.18359375, -0.04...
# 1  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 2  [[-0.055908203, 0.33007812, -0.39648438, 0.017...
# 3  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 4  [[-0.021484375, -0.0037994385, -0.114746094, -...
#
#                                           vector_avg        similar
# 0  [0.07995111, 0.07051823, 0.06434508, 0.0843439...  traffic light
# 1  [0.04933966, 0.012969971, -0.029572986, 0.0616...      surfboard
# 2  [0.032204077, 0.088930055, -0.049434863, 0.037...        giraffe
# 3  [-0.02268982, 0.087446496, 0.03933277, 0.06695...         toilet
# 4  [0.04842315, 0.0264707, -0.008286966, 0.109912...  traffic light

# %% [markdown]
# ## Classification and testing

# %% [markdown]
# #### Cosine similarity of category and vector_avg

# %%
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(df["category"], df["similar"])
print("Accuracy: %0.2f" % (score))
# Out:
# Accuracy: 0.91

# %% [markdown]
# #### Logistic regression

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %%
# Returns the mean accuracy on the given test data and labels, in 5 cross validation splits
scores = cross_val_score(classifier, 
                         pd.DataFrame(df["vector_avg"].tolist()), 
                         df["category"].values, 
                         cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.95 (+/- 0.01)

# %% [markdown]
# #### Linear SVC

# %%
from sklearn.svm import LinearSVC
classifier = LinearSVC()

# %%
# Returns the mean accuracy on the given test data and labels, in 5 cross validation splits
scores = cross_val_score(classifier, 
                         pd.DataFrame(df["vector_avg"].tolist()), 
                         df["category"].values, 
                         cv=5)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.96 (+/- 0.02)

# %%
from sklearn.model_selection import cross_val_predict

df["predictions"] = cross_val_predict(classifier, 
                                      pd.DataFrame(df["vector_avg"].tolist()), 
                                      df["category"].values, 
                                      cv=5)
df[:5]
# Out:
#                                       all_categories  \
# 0  [bus, person, person, person, person, car, car...
# 1  [person, person, person, person, person, perso...
# 2                  [person, giraffe, person, person]
# 3  [bottle, refrigerator, oven, spoon, spoon, bot...
# 4  [car, car, car, car, car, car, traffic light, ...
#
#                                             captions       category  \
# 0  A city street show cars going up and down the ...  traffic light
# 1  Woman in wet suit considers waves near foreste...      surfboard
# 2  A giraffe stands alone outdoors at the zoo. A ...        giraffe
# 3  An oven with a stove, pots and utensils, and a...          clock
# 4  A post office box is on the side of a busy str...  traffic light
#
#           file_name  img_id  \
# 0  000000350023.jpg  350023
# 1  000000059635.jpg   59635
# 2  000000471567.jpg  471567
# 3  000000384661.jpg  384661
# 4  000000496722.jpg  496722
#
#                                                words  \
# 0  [city, street, show, cars, going, up, and, dow...
# 1  [woman, in, wet, suit, considers, waves, near,...
# 2  [giraffe, stands, alone, outdoors, at, the, zo...
# 3  [an, oven, with, stove, pots, and, utensils, a...
# 4  [post, office, box, is, on, the, side, of, bus...
#
#                                              vectors  \
# 0  [[-0.010070801, 0.057373047, 0.18359375, -0.04...
# 1  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 2  [[-0.055908203, 0.33007812, -0.39648438, 0.017...
# 3  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 4  [[-0.021484375, -0.0037994385, -0.114746094, -...
#
#                                           vector_avg        similar  \
# 0  [0.07995111, 0.07051823, 0.06434508, 0.0843439...  traffic light
# 1  [0.04933966, 0.012969971, -0.029572986, 0.0616...      surfboard
# 2  [0.032204077, 0.088930055, -0.049434863, 0.037...        giraffe
# 3  [-0.02268982, 0.087446496, 0.03933277, 0.06695...         toilet
# 4  [0.04842315, 0.0264707, -0.008286966, 0.109912...  traffic light
#
#      predictions
# 0  traffic light
# 1      surfboard
# 2        giraffe
# 3          clock
# 4  traffic light

# %% [markdown]
# ## Misclassified

# %%
k1 = df.loc[(df.category != df.predictions)]
k1 = k1.sample(frac=1).reset_index(drop=True)
k1
# Out:
#                                        all_categories  \
# 0   [dog, dog, chair, person, bed, book, book, boo...
# 1   [chair, person, wine glass, fork, knife, bowl,...
# 2   [cat, cat, person, bottle, cat, fire hydrant, ...
# 3           [car, car, car, person, car, toilet, car]
# 4   [dog, boat, boat, person, person, person, pers...
# 5   [bed, bed, person, toilet, backpack, bottle, b...
# 6   [clock, person, hot dog, donut, donut, donut, ...
# 7   [motorcycle, person, person, person, person, p...
# 8   [cell phone, car, car, car, person, person, pe...
# 9   [umbrella, tie, person, person, person, person...
# 10  [potted plant, refrigerator, chair, cup, cup, ...
# 11  [sandwich, car, chair, dining table, person, p...
# 12                      [horse, clock, clock, person]
# 13  [bottle, person, wine glass, bowl, vase, spoon...
# 14  [dog, person, person, person, person, person, ...
# 15  [bicycle, train, person, tie, bench, bench, ba...
# 16         [dog, motorcycle, bicycle, bicycle, truck]
# 17  [bottle, bottle, bottle, bottle, person, tenni...
# 18                      [dog, person, bench, bicycle]
# 19  [sandwich, clock, person, person, person, pers...
# 20  [kite, kite, person, dog, person, person, pers...
# 21  [bottle, bottle, bottle, bottle, bottle, perso...
# 22  [tv, tv, mouse, keyboard, person, person, pers...
# 23  [bottle, clock, bottle, bottle, bottle, bottle...
# 24                                     [train, clock]
# 25  [person, person, person, skateboard, person, p...
# 26  [bottle, clock, dining table, person, person, ...
# 27  [toilet, bowl, bowl, bowl, sink, sink, sink, v...
# 28  [car, person, frisbee, traffic light, traffic ...
# 29  [dog, cow, cow, cow, cow, cow, cow, cow, cow, ...
# 30  [bus, person, person, person, person, person, ...
# 31  [tv, couch, person, person, clock, donut, book...
# 32  [person, baseball bat, car, car, car, car, tra...
# 33                  [car, person, cat, car, car, car]
# 34  [chair, chair, dining table, person, fork, for...
# 35  [umbrella, umbrella, person, person, person, p...
# 36  [bottle, bottle, bottle, car, car, traffic lig...
# 37                            [tv, cat, couch, chair]
# 38  [tv, person, person, remote, couch, clock, clo...
# 39  [dog, person, person, frisbee, kite, person, p...
# 40  [tv, cat, couch, chair, book, book, chair, boo...
# 41  [bicycle, bicycle, bicycle, backpack, backpack...
# 42                       [person, cake, spoon, clock]
# 43                 [bird, giraffe, cow, potted plant]
# 44                           [person, remote, toilet]
# 45  [dog, person, person, boat, boat, boat, umbrel...
# 46  [train, person, person, person, person, person...
# 47  [bottle, chair, chair, dining table, dining ta...
# 48  [train, person, person, person, clock, person,...
# 49  [couch, person, person, remote, remote, remote...
# 50  [dog, horse, person, person, person, person, b...
# 51  [umbrella, person, traffic light, traffic ligh...
# 52  [potted plant, potted plant, potted plant, pot...
# 53  [cell phone, person, tennis racket, laptop, bo...
#
#                                              captions       category  \
# 0   A man sitting at a computer desk in front of a...            dog
# 1   An individual is capture in the stillness of t...          pizza
# 2   A woman in yellow shirt and skirt with cats in...            cat
# 3   A young attractive woman sitting on a toilette...         toilet
# 4   Sail boats sail over a body of water while peo...            dog
# 5   A young woman using a laptop computer while si...         toilet
# 6   This a case full of doughnuts and cinnamon bun...          clock
# 7   A street scene with a person on a motorcycle. ...            dog
# 8   A man is taking a photo of a city with his pho...  traffic light
# 9   A newly married couple walking down a street. ...  traffic light
# 10  A smaller kitchen with a very decorated fridge...      surfboard
# 11  A man taking a picture of plates of food. a ma...          clock
# 12  A woman exercising a brown horse in a riding r...          clock
# 13  A man looking at camera preparing food in kitc...          pizza
# 14  a person riding a skate board on a city street...            dog
# 15  the man is working on his laptop while he wait...  traffic light
# 16  a small motor bike outside of the garage A tri...            dog
# 17  The man holds a ping pong paddle under the she...  tennis racket
# 18  A man is riding a large bike through the park....            dog
# 19  a close up of a person holding up a plate of f...          clock
# 20  many people on a beach with a kite flying in t...            dog
# 21  a man and woman standing side by side in a kit...          pizza
# 22  The computer monitor has a framed picture near...            cat
# 23  A group of older people around a long restaura...          clock
# 24  A high speed train is seen in the station. A t...          clock
# 25  A young man riding a skateboard with an older ...      surfboard
# 26  A group of people sitting around a wooden tabl...          clock
# 27  Ten porcelain pieces with floral patterns pain...         toilet
# 28  A girl is playing in a grassy area. a woman on...  traffic light
# 29  A bunch of cows that are standing in the grass...            dog
# 30  A black and white image with a colored british...          clock
# 31  A little boy is being held on a lap while eati...          clock
# 32  Kid poses for a picture in a baseball uniform ...  traffic light
# 33  an image of a night scene with a cat on top of...            cat
# 34  A boy getting ready to blow out candles on a b...          pizza
# 35  A group of people standing and sitting on top ...            dog
# 36  a man standing in front of the grill of a  hot...  traffic light
# 37  a cat laying on top of a chair in the living r...            cat
# 38  A couple of men in front of a television with ...          clock
# 39  people on a gold course enjoy a few games  A p...            dog
# 40  A living room filled with furniture and a flat...            cat
# 41  a gathering outside on the lawn of city hall A...          pizza
# 42  A woman with glasses eating a piece of cake. a...          clock
# 43  Set of toy animals sitting in front of a red w...        giraffe
# 44  A man holding holding a giant remote control. ...         toilet
# 45  Man and woman with umbrella hats sitting on to...            dog
# 46  a red train is docked at the station Several p...          clock
# 47  The two teens are playing video games in the r...          pizza
# 48  A passenger train is sitting at a station. A t...          clock
# 49  A couple of women holding game controllers in ...            dog
# 50  A horse pulling  carriage travels through a bu...            dog
# 51  this person is leaving footprints in the snow ...  traffic light
# 52  A cat in front of a wooden bench in a garden. ...            cat
# 53  there is a tennis racket and a laptop on the f...  tennis racket
#
#            file_name  img_id  \
# 0   000000366884.jpg  366884
# 1   000000425361.jpg  425361
# 2   000000375493.jpg  375493
# 3   000000365642.jpg  365642
# 4   000000078565.jpg   78565
# 5   000000393569.jpg  393569
# 6   000000405195.jpg  405195
# 7   000000139099.jpg  139099
# 8   000000545100.jpg  545100
# 9   000000496854.jpg  496854
# 10  000000407614.jpg  407614
# 11  000000350148.jpg  350148
# 12  000000015956.jpg   15956
# 13  000000473869.jpg  473869
# 14  000000279278.jpg  279278
# 15  000000076547.jpg   76547
# 16  000000007386.jpg    7386
# 17  000000112298.jpg  112298
# 18  000000289343.jpg  289343
# 19  000000045550.jpg   45550
# 20  000000057760.jpg   57760
# 21  000000520264.jpg  520264
# 22  000000149222.jpg  149222
# 23  000000031296.jpg   31296
# 24  000000159684.jpg  159684
# 25  000000087476.jpg   87476
# 26  000000009590.jpg    9590
# 27  000000571804.jpg  571804
# 28  000000442746.jpg  442746
# 29  000000415990.jpg  415990
# 30  000000233771.jpg  233771
# 31  000000084674.jpg   84674
# 32  000000491464.jpg  491464
# 33  000000167122.jpg  167122
# 34  000000180101.jpg  180101
# 35  000000143961.jpg  143961
# 36  000000213255.jpg  213255
# 37  000000366141.jpg  366141
# 38  000000491366.jpg  491366
# 39  000000471789.jpg  471789
# 40  000000139684.jpg  139684
# 41  000000507037.jpg  507037
# 42  000000327592.jpg  327592
# 43  000000289393.jpg  289393
# 44  000000037670.jpg   37670
# 45  000000534270.jpg  534270
# 46  000000146825.jpg  146825
# 47  000000091500.jpg   91500
# 48  000000369675.jpg  369675
# 49  000000371749.jpg  371749
# 50  000000463522.jpg  463522
# 51  000000248284.jpg  248284
# 52  000000279145.jpg  279145
# 53  000000035279.jpg   35279
#
#                                                 words  \
# 0   [man, sitting, at, computer, desk, in, front, ...
# 1   [an, individual, is, capture, in, the, stillne...
# 2   [woman, in, yellow, shirt, and, skirt, with, c...
# 3   [young, attractive, woman, sitting, on, toilet...
# 4   [sail, boats, sail, over, body, of, water, whi...
# 5   [young, woman, using, laptop, computer, while,...
# 6   [this, case, full, of, doughnuts, and, cinnamo...
# 7   [street, scene, with, person, on, motorcycle, ...
# 8   [man, is, taking, photo, of, city, with, his, ...
# 9   [newly, married, couple, walking, down, street...
# 10  [smaller, kitchen, with, very, decorated, frid...
# 11  [man, taking, picture, of, plates, of, food, m...
# 12  [woman, exercising, brown, horse, in, riding, ...
# 13  [man, looking, at, camera, preparing, food, in...
# 14  [person, riding, skate, board, on, city, stree...
# 15  [the, man, is, working, on, his, laptop, while...
# 16  [small, motor, bike, outside, of, the, garage,...
# 17  [the, man, holds, ping, pong, paddle, under, t...
# 18  [man, is, riding, large, bike, through, the, p...
# 19  [close, up, of, person, holding, up, plate, of...
# 20  [many, people, on, beach, with, kite, flying, ...
# 21  [man, and, woman, standing, side, by, side, in...
# 22  [the, computer, monitor, has, framed, picture,...
# 23  [group, of, older, people, around, long, resta...
# 24  [high, speed, train, is, seen, in, the, statio...
# 25  [young, man, riding, skateboard, with, an, old...
# 26  [group, of, people, sitting, around, wooden, t...
# 27  [ten, porcelain, pieces, with, floral, pattern...
# 28  [girl, is, playing, in, grassy, area, woman, o...
# 29  [bunch, of, cows, that, are, standing, in, the...
# 30  [black, and, white, image, with, colored, brit...
# 31  [little, boy, is, being, held, on, lap, while,...
# 32  [kid, poses, for, picture, in, baseball, unifo...
# 33  [an, image, of, night, scene, with, cat, on, t...
# 34  [boy, getting, ready, to, blow, out, candles, ...
# 35  [group, of, people, standing, and, sitting, on...
# 36  [man, standing, in, front, of, the, grill, of,...
# 37  [cat, laying, on, top, of, chair, in, the, liv...
# 38  [couple, of, men, in, front, of, television, w...
# 39  [people, on, gold, course, enjoy, few, games, ...
# 40  [living, room, filled, with, furniture, and, f...
# 41  [gathering, outside, on, the, lawn, of, city, ...
# 42  [woman, with, glasses, eating, piece, of, cake...
# 43  [set, of, toy, animals, sitting, in, front, of...
# 44  [man, holding, holding, giant, remote, control...
# 45  [man, and, woman, with, umbrella, hats, sittin...
# 46  [red, train, is, docked, at, the, station, sev...
# 47  [the, two, teens, are, playing, video, games, ...
# 48  [passenger, train, is, sitting, at, station, t...
# 49  [couple, of, women, holding, game, controllers...
# 50  [horse, pulling, carriage, travels, through, b...
# 51  [this, person, is, leaving, footprints, in, th...
# 52  [cat, in, front, of, wooden, bench, in, garden...
# 53  [there, is, tennis, racket, and, laptop, on, t...
#
#                                               vectors  \
# 0   [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 1   [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 2   [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 3   [[0.09472656, 0.328125, -0.048583984, -0.00665...
# 4   [[0.22363281, 0.43359375, -0.20117188, -0.0125...
# 5   [[0.09472656, 0.328125, -0.048583984, -0.00665...
# 6   [[0.109375, 0.140625, -0.03173828, 0.16601562,...
# 7   [[0.09814453, 0.075683594, 0.030883789, 0.1787...
# 8   [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 9   [[-0.044189453, -0.123046875, 0.12597656, -0.1...
# 10  [[-0.050048828, 0.034179688, -0.0703125, 0.175...
# 11  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 12  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 13  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 14  [[0.27539062, -0.24707031, 0.017211914, 0.1679...
# 15  [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 16  [[0.15917969, 0.095703125, -0.125, 0.10253906,...
# 17  [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 18  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 19  [[-0.0032043457, -0.07080078, 0.08984375, 0.21...
# 20  [[0.19335938, -0.004333496, -0.032226562, 0.13...
# 21  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 22  [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 23  [[-0.021972656, 0.015197754, -0.029907227, 0.0...
# 24  [[0.076660156, 0.00970459, -0.080078125, 0.181...
# 25  [[0.09472656, 0.328125, -0.048583984, -0.00665...
# 26  [[-0.021972656, 0.015197754, -0.029907227, 0.0...
# 27  [[0.0058898926, -0.09814453, 0.028320312, 0.20...
# 28  [[0.13867188, 0.0037384033, 0.064453125, -0.07...
# 29  [[0.05419922, 0.1953125, -0.010986328, 0.28125...
# 30  [[0.10498047, 0.018432617, 0.008972168, -0.012...
# 31  [[0.18945312, 0.13671875, -0.09472656, 0.24218...
# 32  [[0.18457031, 0.14941406, 0.09082031, 0.310546...
# 33  [[0.12597656, 0.19042969, 0.06982422, 0.072265...
# 34  [[0.23535156, 0.16503906, 0.09326172, -0.12890...
# 35  [[-0.021972656, 0.015197754, -0.029907227, 0.0...
# 36  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 37  [[0.012329102, 0.20410156, -0.28515625, 0.2167...
# 38  [[0.09667969, -0.0032653809, -0.37109375, 0.10...
# 39  [[0.26367188, -0.019165039, 0.028930664, 0.234...
# 40  [[0.1328125, 0.10644531, -0.07763672, 0.182617...
# 41  [[0.14550781, 0.16503906, 0.049804688, 0.09619...
# 42  [[0.24316406, -0.07714844, -0.103027344, -0.10...
# 43  [[0.029541016, 0.25976562, 0.19335938, 0.08837...
# 44  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 45  [[0.32617188, 0.13085938, 0.03466797, -0.08300...
# 46  [[0.09716797, -0.08496094, 0.27148438, 0.22167...
# 47  [[0.080078125, 0.10498047, 0.049804688, 0.0534...
# 48  [[0.51171875, -0.06347656, 0.23242188, 0.00891...
# 49  [[0.09667969, -0.0032653809, -0.37109375, 0.10...
# 50  [[0.0005340576, 0.03112793, 0.0050354004, -0.0...
# 51  [[0.109375, 0.140625, -0.03173828, 0.16601562,...
# 52  [[0.012329102, 0.20410156, -0.28515625, 0.2167...
# 53  [[0.09423828, -0.022827148, 0.052246094, 0.026...
#
#                                            vector_avg        similar  \
# 0   [0.06266062, 0.044794988, 0.0012399774, 0.0781...         toilet
# 1   [0.01859116, 0.051346943, -0.02416192, 0.06112...          pizza
# 2   [0.07454224, 0.03916931, 0.02020874, 0.0478256...            dog
# 3   [0.09142665, 0.007317794, -0.00028429533, 0.10...         toilet
# 4   [0.09650697, 0.10090093, -0.051098112, 0.06210...      surfboard
# 5   [0.06295634, -0.0036450764, 0.04265364, 0.0957...         toilet
# 6   [-0.00797035, 0.025007578, -0.049233273, 0.186...          pizza
# 7   [0.08060455, -0.013256497, -0.0058034263, 0.10...            dog
# 8   [0.053505316, 0.078639336, 0.008547899, -0.021...            dog
# 9   [0.040103912, -0.025392914, -0.01187439, 0.012...            dog
# 10  [-0.055013802, 0.08017437, -0.016232222, 0.078...         toilet
# 11  [0.036826324, 0.09107259, 0.014297994, 0.10852...          pizza
# 12  [0.063723974, 0.03292411, 0.0018511091, 0.0037...            dog
# 13  [0.021338211, 0.1048327, 0.04833904, 0.0645623...          pizza
# 14  [0.09721039, 0.010206269, 0.04754341, 0.113809...            dog
# 15  [0.05719968, 0.044478722, 0.0673893, 0.0495332...            dog
# 16  [0.060295336, 0.03913648, -0.00091645215, 0.03...      surfboard
# 17  [0.02190986, 0.010273273, 0.013679749, 0.07203...  tennis racket
# 18  [0.10161656, 0.008689662, 0.009137834, 0.10111...            dog
# 19  [-0.0018467759, 0.060885344, 0.030042706, 0.14...          pizza
# 20  [0.09510597, 0.01770999, -0.02956081, 0.091790...      surfboard
# 21  [0.05921444, 0.03323315, 0.016690655, 0.036396...         toilet
# 22  [0.027858611, -0.044955898, -0.05519055, 0.043...  tennis racket
# 23  [0.004035102, 0.022254096, 0.0072619966, 0.176...          pizza
# 24  [0.009081041, 0.10517677, 0.064845726, 0.04908...  traffic light
# 25  [0.11482043, 0.013994266, 0.047851365, 0.08769...      surfboard
# 26  [0.0048433193, 0.03782205, 0.031207366, 0.1744...          pizza
# 27  [-0.025797525, 0.09048971, 0.0127682155, 0.132...         toilet
# 28  [0.11844532, 0.06442096, 0.055497248, 0.048981...            dog
# 29  [0.05001028, 0.06538954, 0.020808972, 0.065958...            dog
# 30  [0.032677915, 0.05935474, 0.038118403, 0.08287...            dog
# 31  [0.051161025, 0.043923102, 0.034996543, 0.0655...            dog
# 32  [-0.00027678732, 0.15596612, 0.07994754, 0.023...  tennis racket
# 33  [0.06637641, 0.07597605, -0.0012049357, 0.0532...            dog
# 34  [0.10837446, 0.03699203, 0.056565057, 0.085981...          pizza
# 35  [0.052807618, 0.026527405, 0.03807373, 0.12752...         toilet
# 36  [0.051148526, 0.07332452, 0.021673867, 0.12197...            dog
# 37  [0.05642935, 0.0016420316, 0.01592284, 0.12165...         toilet
# 38  [0.04059268, 0.02849442, 0.012792342, 0.071255...  tennis racket
# 39  [0.06650337, 0.04913495, -0.020373577, 0.10593...           skis
# 40  [0.037010524, 0.058023203, 0.00876294, 0.11404...         toilet
# 41  [-0.0017282587, 0.03427124, 0.049038135, 0.110...          pizza
# 42  [-0.0062092626, 0.0034012462, 0.013139415, 0.1...          pizza
# 43  [0.08370209, 0.081186995, -0.040471327, 0.1330...            cat
# 44  [0.08915138, 0.024242401, -0.038812637, 0.0623...         toilet
# 45  [0.018541971, 0.00088773173, -0.027387619, 0.0...            dog
# 46  [0.025868734, 0.06388033, 0.059446678, 0.04288...         toilet
# 47  [0.052502442, 0.026852757, 0.04134674, 0.09458...  tennis racket
# 48  [0.056766763, 0.06975282, 0.06623925, 0.064160...  traffic light
# 49  [0.045386273, 0.032844212, 0.012589662, 0.0735...         toilet
# 50  [0.05004548, 0.059888374, 0.023850603, 0.06431...            dog
# 51  [0.06998825, 0.01692276, 0.03663025, 0.0459045...            dog
# 52  [0.09951285, 0.13124688, 0.07675313, 0.1154907...            cat
# 53  [0.076261654, 0.013311341, 0.056695893, 0.0601...  tennis racket
#
#       predictions
# 0           clock
# 1           clock
# 2   traffic light
# 3   traffic light
# 4       surfboard
# 5           clock
# 6           pizza
# 7   traffic light
# 8           clock
# 9           clock
# 10          clock
# 11          pizza
# 12            dog
# 13          clock
# 14  traffic light
# 15          clock
# 16  traffic light
# 17          clock
# 18  traffic light
# 19          pizza
# 20      surfboard
# 21          clock
# 22          clock
# 23          pizza
# 24  traffic light
# 25  traffic light
# 26          pizza
# 27          clock
# 28            dog
# 29        giraffe
# 30  traffic light
# 31          pizza
# 32  tennis racket
# 33  traffic light
# 34          clock
# 35          clock
# 36            dog
# 37          clock
# 38  tennis racket
# 39           skis
# 40          clock
# 41          clock
# 42          pizza
# 43            dog
# 44          clock
# 45  traffic light
# 46  traffic light
# 47  tennis racket
# 48  traffic light
# 49          clock
# 50  traffic light
# 51           skis
# 52          clock
# 53          clock

# %%
k1["captions"][2]
# Out:
# 'A woman in yellow shirt and skirt with cats in grass. a person standing next to a yellow fire hydrant A woman wearing a jean skirt standing next to a fire hydrant. a woman standing next to a yellow fire hydrant A woman wearing a yellow top and a jean skirt standing next to a yellow fire hydrant. '
